# %%
# !pwd
# Out:
# /Users/vadramandisang/Documents/Vadrama/data/Product/ViaMichelin_Scraping

# %%
# !pip install sqlalchemy
# Out:
# Requirement already satisfied: sqlalchemy in /Users/vadramandisang/opt/anaconda3/lib/python3.8/site-packages (1.4.7)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/vadramandisang/opt/anaconda3/lib/python3.8/site-packages (from sqlalchemy) (1.0.0)

# %%
# !pip3 install deepparse
# Out:
# Requirement already satisfied: deepparse in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (0.9.5)
# Requirement already satisfied: fasttext in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from deepparse) (0.9.2)
# Requirement already satisfied: poutyne in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from deepparse) (1.14)
# Requirement already satisfied: gensim>=4.0.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from deepparse) (4.3.0)
# Requirement already satisfied: pymagnitude-light in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from deepparse) (0.1.147)
# Requirement already satisfied: urllib3 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from deepparse) (1.26.14)
# Requirement already satisfied: torch in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from deepparse) (1.13.1)
# Requirement already satisfied: requests in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from deepparse) (2.28.1)
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from deepparse) (1.24.1)
# Requirement already satisfied: bpemb in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from deepparse) (0.3.4)
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from deepparse) (1.5.2)
# Requirement already satisfied: scipy>=1.7.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from gensim>=4.0.0->deepparse) (1.10.1)
# Requirement already satisfied: FuzzyTM>=0.4.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from gensim>=4.0.0->deepparse) (2.0.5)
# Requirement already satisfied: smart-open>=1.8.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from gensim>=4.0.0->deepparse) (6.3.0)
# Requirement already satisfied: tqdm in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from bpemb->deepparse) (4.64.1)
# Requirement already satisfied: sentencepiece in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from bpemb->deepparse) (0.1.97)
# Requirement already satisfied: pybind11>=2.2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from fasttext->deepparse) (2.10.3)
# Requirement already satisfied: setuptools>=0.7.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from fasttext->deepparse) (65.5.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pandas->deepparse) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pandas->deepparse) (2022.7)
# Requirement already satisfied: torchmetrics in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from poutyne->deepparse) (0.11.3)
# Requirement already satisfied: xxhash>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pymagnitude-light->deepparse) (3.2.0)
# Requirement already satisfied: lz4>=1.0.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pymagnitude-light->deepparse) (4.3.2)
# Requirement already satisfied: fasteners>=0.14.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pymagnitude-light->deepparse) (0.18)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests->deepparse) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests->deepparse) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests->deepparse) (2022.12.7)
# Requirement already satisfied: typing-extensions in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from torch->deepparse) (4.4.0)
# Requirement already satisfied: pyfume in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from FuzzyTM>=0.4.0->gensim>=4.0.0->deepparse) (0.2.25)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas->deepparse) (1.16.0)
# Requirement already satisfied: packaging in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from torchmetrics->poutyne->deepparse) (23.0)
# Requirement already satisfied: simpful in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyfume->FuzzyTM>=0.4.0->gensim>=4.0.0->deepparse) (2.10.0)
# Requirement already satisfied: fst-pso in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyfume->FuzzyTM>=0.4.0->gensim>=4.0.0->deepparse) (1.8.1)
# Requirement already satisfied: miniful in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from fst-pso->pyfume->FuzzyTM>=0.4.0->gensim>=4.0.0->deepparse) (0.0.6)
#
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: pip3 install --upgrade pip

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import uuid
import hashlib
from snowflake.sqlalchemy import URL
from sqlalchemy import create_engine
import json
from geopy.geocoders import Nominatim
from deepparse.parser import AddressParser
from deepparse.dataset_container import CSVDatasetContainer

address_parser = AddressParser(model_type="bpemb", device=0)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [74], in <cell line: 10>()
#       8 import json
#       9 from geopy.geocoders import Nominatim
# ---> 10 from deepparse.parser import AddressParser
#      11 from deepparse.dataset_container import CSVDatasetContainer
#      13 address_parser = AddressParser(model_type="bpemb", device=0)
#
# ModuleNotFoundError: No module named 'deepparse'

# %%
# Load the Snowflake configuration from the JSON file
with open("snow_cred.json") as f:
    config = json.load(f)
    
    
# Creating Snowflake Connection
snow_engine = create_engine(URL(
    account = config['account'],
    user = config['user'],
    password = config['password'],
    database = config['database'],
    schema = config['schema'],
    warehouse = config['warehouse'],
    role= config['role']
))

snow_connection = snow_engine.connect()
snow_connection

# %%
country_url_list = ['https://www.viamichelin.fr/web/Stations-service?address=Czechia',]
countries = ['France', 'United Kingdom', 'Switzerland', 'Germany', 'Belgium', 'Netherlands', 'Spain', 'Luxembourg', 'Czech Republic', 'Italy']
# 'https://www.viamichelin.fr/web/Stations-service?address=France',

# %%
countries = ['France', 'United Kingdom', 'Switzerland', 'Germany', 'Belgium', 'Netherlands', 'Spain', 'Luxembourg', 'Czech Republic', 'Italy']

country_url_list = ['https://www.viamichelin.fr/web/Stations-service?address=France', 'https://www.viamichelin.fr/web/Stations-service?address=united%20kingdom', 'https://www.viamichelin.fr/web/Stations-service?address=switzerland', 'https://www.viamichelin.fr/web/Stations-service?address=germany', 'https://www.viamichelin.fr/web/Stations-service?address=Belgium', 'https://www.viamichelin.fr/web/Stations-service?address=netherlands', 'https://www.viamichelin.fr/web/Stations-service?address=spain', 'https://www.viamichelin.fr/web/Stations-service?address=luxemburg', 'https://www.viamichelin.fr/web/Stations-service?address=Czechia', 'https://www.viamichelin.fr/web/Stations-service?address=Italy']

# %% [markdown]
# ## Working Script

# %%
def get_street(address, station_address):
    if 'house_number' in address:
        if address['house_number'] in station_address.split():
            street = str(address['house_number']) + ' ' + str(address['road']) if 'road' in address else ''
        else:
            street = str(address['road']) if 'road' in address else ''
    else:
        street = str(address['road']) if 'road' in address else ''
        
    return street


def get_city(address):
    if 'city' in address:
        city = address['city']
    elif 'town' in address: 
        city = address['town']
    elif 'village' in address: 
        city = address['village']    
    else:
        city = ''
    return city



# Enrich Station Address
def split_address(station_address, country):
    enriched_address = []
    for i, ct in zip(station_address, country):  # url, ctry in zip(country_url_list, countries)
        new_station_address = []
        location = geolocator.geocode(i) # 18 Hauptstrasse, 3752 Wimmis
        #print(type(location))
        if location:
            #print(location.raw)
            lat = location.raw['lat']
            lon = location.raw['lon']
            location_geop = geolocator.reverse(f"{lat}, {lon}")
            address = location_geop.raw['address']
            postcode = str(address['postcode']) if 'postcode' in address else ''
            place_id = str(location_geop.raw['place_id']) if 'place_id' in location_geop.raw else ''
            station_street = get_street(address, i)
            station_city = get_city(address)
            #print(location_geop.raw)    
            new_station_address.extend([station_street, station_city, postcode, lat, lon, place_id,ct])
            enriched_address.append(new_station_address)
        else:
            #print("Location not found")
            new_station_address.extend(['', '', '', '', '', '', ct])
            enriched_address.append(new_station_address)
    #print(type(enriched_address), '\nNow Appending enriched_address...')                    
    enriched_address_df = pd.DataFrame(enriched_address, columns = ['Street', 'City', 'Postcode', 'Latitude', 'Longitude', 'Place_id', 'Country'])
    return enriched_address_df


def save_data(data_df):
    target_table = 'viamichelin_stations'
    del_id_lst = str(list(data_df['id'])).replace('[','(').replace(']',')') 
    try:
        # Delete existing rows to be updated with new version
        del_existing_rows_query = "DELETE FROM " +target_table+ " WHERE id IN " + del_id_lst
        #print('Del Query is ', del_existing_rows_query)
        with snow_engine.connect() as conn:
            conn.execute(del_existing_rows_query)

        # Save data in the DataFrame    
        data_df.to_sql(target_table, con=snow_engine, schema='EXTERNAL_TABLES', index=False, if_exists='append')
        print(data_df.loc[0])
        data_df = pd.DataFrame()
    except Exception as err:
        print(err)

# %%
def save_data_new(data_df):
    target_table = 'viamichelin_stations'
    del_id_lst = str(list(data_df['id'])).replace('[','(').replace(']',')') 
    try:
        # Delete existing rows to be updated with new version
        del_existing_rows_query = "DELETE FROM " +target_table+ " WHERE id IN " + del_id_lst
        #print('Del Query is ', del_existing_rows_query)
        with snow_engine.connect() as conn:
            conn.execute(del_existing_rows_query)

        # Save data in the DataFrame    
        data_df.to_sql(target_table, con=snow_engine, schema='EXTERNAL_TABLES', index=False, if_exists='append')
        print(data_df.loc[0])
        data_df = pd.DataFrame()
    except Exception as err:
        print(err)

# %%
try:
    get_tab_df = pd.read_sql_query(" SELECT * FROM STATION_SERVICE.PUBLIC.VIAMICHELIN_STATIONS WHERE ID NOT IN (SELECT ID FROM STATION_SERVICE.EXTERNAL_TABLES.VIAMICHELIN_STATIONS) ORDER BY COUNTRY ASC", snow_engine)
    #snw_slc_to_pg_df.to_sql(f'{tab}', pg_engine, if_exists='replace', index=False)
    #print(get_tab_df)
except Exception as error:
    print('Error Occured')
    print(error)
    sys.exit(1)

# %%
len(get_tab_df)
# Out:
# 43784

# %%
temp_df
# Out:
#                      Street        City Postcode     Latitude  \
# 0
# 1
# 2
# 3
# 4        Rue des Tisserands  Hilsenheim    67600   48.2812644
# 5      Boulevard de Guizard    Espalion    12500   44.5235849
# 6  Boulevard de la Chapelle       Paris    75010  48.88367915
# 7
# 8
# 9      57 Route de Rouffach      Colmar    68000   48.0673483
#
#             Longitude   Place_id Country
# 0                                 France
# 1                                 France
# 2                                 France
# 3                                 France
# 4           7.5547576   75854100  France
# 5           2.7638757   44041847  France
# 6  2.3560908524463007  198541775  France
# 7                                 France
# 8                                 France
# 9            7.343814    5346274  France

# %%
# %%time
temp_df = split_address(list(get_tab_df['station_address']), list(get_tab_df['country']))
len(temp_df)
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~/opt/anaconda3/envs/route_env/lib/python3.10/site-packages/urllib3/connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~/opt/anaconda3/envs/route_env/lib/python3.10/site-packages/urllib3/connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443 try:
# --> 444     httplib_response = conn.getresponse()
#     445 except BaseException as e:
#     446     # Remove the TypeError from the exception chain in
#     447     # Python 3 (including for exceptions like SystemExit).
#     448     # Otherwise it looks like a bug in the code.
#
# File ~/opt/anaconda3/envs/route_env/lib/python3.10/http/client.py:1374, in HTTPConnection.getresponse(self)
#    1373 try:
# -> 1374     response.begin()
#    1375 except ConnectionError:
#
# File ~/opt/anaconda3/envs/route_env/lib/python3.10/http/client.py:318, in HTTPResponse.begin(self)
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#
# File ~/opt/anaconda3/envs/route_env/lib/python3.10/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#
# File ~/opt/anaconda3/envs/route_env/lib/python3.10/socket.py:705, in SocketIO.readinto(self, b)
#     704 try:
# --> 705     return self._sock.recv_into(b)
#     706 except timeout:
#
# File ~/opt/anaconda3/envs/route_env/lib/python3.10/ssl.py:1274, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1271         raise ValueError(
#    1272           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1273           self.__class__)
# -> 1274     return self.read(nbytes, buffer)
#    1275 else:
#
# File ~/opt/anaconda3/envs/route_env/lib/python3.10/ssl.py:1130, in SSLSocket.read(self, len, buffer)
#    1129 if buffer is not None:
# -> 1130     return self._sslobj.read(len, buffer)
#    1131 else:
#
# TimeoutError: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeoutError                          Traceback (most recent call last)
# File ~/opt/anaconda3/envs/route_env/lib/python3.10/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#
# File ~/opt/anaconda3/envs/route_env/lib/python3.10/site-packages/urllib3/connectionpool.py:451, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
# --> 451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#     452     raise
#
# File ~/opt/anaconda3/envs/route_env/lib/python3.10/site-packages/urllib3/connectionpool.py:340, in HTTPConnectionPool._raise_timeout(self, err, url, timeout_value)
#     339 if isinstance(err, SocketTimeout):
# --> 340     raise ReadTimeoutError(
#     341         self, url, "Read timed out. (read timeout=%s)" % timeout_value
#     342     )
#     344 # See the above comment about EAGAIN in Python 3. In Python 2 we have
#     345 # to specifically catch it and throw the timeout error
#
# ReadTimeoutError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# File ~/opt/anaconda3/envs/route_env/lib/python3.10/site-packages/requests/adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     488 if not chunked:
# --> 489     resp = conn.urlopen(
#     490         method=request.method,
#     491         url=url,
#     492         body=request.body,
#     493         headers=request.headers,
#     494         redirect=False,
#     495         assert_same_host=False,
#     496         preload_content=False,
#     497         decode_content=False,
#     498         retries=self.max_retries,
#     499         timeout=timeout,
#     500     )
#     502 # Send the request.
#     503 else:
#
# File ~/opt/anaconda3/envs/route_env/lib/python3.10/site-packages/urllib3/connectionpool.py:815, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     812     log.warning(
#     813         "Retrying (%r) after connection broken by '%r': %s", retries, err, url
#     814     )
# --> 815     return self.urlopen(
#     816         method,
#     817         url,
#     818         body,
#     819         headers,
#     820         retries,
#     821         redirect,
#     822         assert_same_host,
#     823         timeout=timeout,
#     824         pool_timeout=pool_timeout,
#     825         release_conn=release_conn,
#     826         chunked=chunked,
#     827         body_pos=body_pos,
#     828         **response_kw
#     829     )
#     831 # Handle redirect?
#
# File ~/opt/anaconda3/envs/route_env/lib/python3.10/site-packages/urllib3/connectionpool.py:815, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     812     log.warning(
#     813         "Retrying (%r) after connection broken by '%r': %s", retries, err, url
#     814     )
# --> 815     return self.urlopen(
#     816         method,
#     817         url,
#     818         body,
#     819         headers,
#     820         retries,
#     821         redirect,
#     822         assert_same_host,
#     823         timeout=timeout,
#     824         pool_timeout=pool_timeout,
#     825         release_conn=release_conn,
#     826         chunked=chunked,
#     827         body_pos=body_pos,
#     828         **response_kw
#     829     )
#     831 # Handle redirect?
#
# File ~/opt/anaconda3/envs/route_env/lib/python3.10/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     785     e = ProtocolError("Connection aborted.", e)
# --> 787 retries = retries.increment(
#     788     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     789 )
#     790 retries.sleep()
#
# File ~/opt/anaconda3/envs/route_env/lib/python3.10/site-packages/urllib3/util/retry.py:592, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     591 if new_retry.is_exhausted():
# --> 592     raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     594 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=BOULEVARD+DE+BEL+AIR%2C+87100+LIMOGES&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# File ~/opt/anaconda3/envs/route_env/lib/python3.10/site-packages/geopy/adapters.py:448, in RequestsAdapter._request(self, url, timeout, headers)
#     447 try:
# --> 448     resp = self.session.get(url, timeout=timeout, headers=headers)
#     449 except Exception as error:
#
# File ~/opt/anaconda3/envs/route_env/lib/python3.10/site-packages/requests/sessions.py:600, in Session.get(self, url, **kwargs)
#     599 kwargs.setdefault("allow_redirects", True)
# --> 600 return self.request("GET", url, **kwargs)
#
# File ~/opt/anaconda3/envs/route_env/lib/python3.10/site-packages/requests/sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~/opt/anaconda3/envs/route_env/lib/python3.10/site-packages/requests/sessions.py:701, in Session.send(self, request, **kwargs)
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#
# File ~/opt/anaconda3/envs/route_env/lib/python3.10/site-packages/requests/adapters.py:565, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     563         raise SSLError(e, request=request)
# --> 565     raise ConnectionError(e, request=request)
#     567 except ClosedPoolError as e:
#
# ConnectionError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=BOULEVARD+DE+BEL+AIR%2C+87100+LIMOGES&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# GeocoderUnavailable                       Traceback (most recent call last)
# File <timed exec>:1, in <module>
#
# Input In [26], in split_address(station_address, country)
#      29 for i, ct in zip(station_address, country):  # url, ctry in zip(country_url_list, countries)
#      30     new_station_address = []
# ---> 31     location = geolocator.geocode(i) # 18 Hauptstrasse, 3752 Wimmis
#      32     #print(type(location))
#      33     if location:
#      34         #print(location.raw)
#
# File ~/opt/anaconda3/envs/route_env/lib/python3.10/site-packages/geopy/geocoders/nominatim.py:297, in Nominatim.geocode(self, query, exactly_one, timeout, limit, addressdetails, language, geometry, extratags, country_codes, viewbox, bounded, featuretype, namedetails)
#     295 logger.debug("%s.geocode: %s", self.__class__.__name__, url)
#     296 callback = partial(self._parse_json, exactly_one=exactly_one)
# --> 297 return self._call_geocoder(url, callback, timeout=timeout)
#
# File ~/opt/anaconda3/envs/route_env/lib/python3.10/site-packages/geopy/geocoders/base.py:368, in Geocoder._call_geocoder(self, url, callback, timeout, is_json, headers)
#     366 try:
#     367     if is_json:
# --> 368         result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#     369     else:
#     370         result = self.adapter.get_text(url, timeout=timeout, headers=req_headers)
#
# File ~/opt/anaconda3/envs/route_env/lib/python3.10/site-packages/geopy/adapters.py:438, in RequestsAdapter.get_json(self, url, timeout, headers)
#     437 def get_json(self, url, *, timeout, headers):
# --> 438     resp = self._request(url, timeout=timeout, headers=headers)
#     439     try:
#     440         return resp.json()
#
# File ~/opt/anaconda3/envs/route_env/lib/python3.10/site-packages/geopy/adapters.py:460, in RequestsAdapter._request(self, url, timeout, headers)
#     458         raise GeocoderServiceError(message)
#     459     else:
# --> 460         raise GeocoderUnavailable(message)
#     461 elif isinstance(error, requests.Timeout):
#     462     raise GeocoderTimedOut("Service timed out")
#
# GeocoderUnavailable: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=BOULEVARD+DE+BEL+AIR%2C+87100+LIMOGES&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))

# %%
# %%time
temP = get_tab_df[['id', 'station_name', 'station_address']]
len(temP)
# Out:
# CPU times: user 3.88 ms, sys: 1.2 ms, total: 5.08 ms
# Wall time: 3.77 ms
# 43784

# %%
# %%time
final_df = pd.concat([temP, temp_df], axis=1)
len(final_df)
# Out:
# CPU times: user 4.88 ms, sys: 2.06 ms, total: 6.94 ms
# Wall time: 5.06 ms
# 43784

# %%
final_df
# Out:
#                                      id              station_name  \
# 0      b7be2e50cb1d5e7b8335e9e6dc6d25e8                     SHELL
# 1      55f54ad09d895c258131ad436b087980      E.LECLERC PLOUFRAGAN
# 2      2a9b0401ff9d5f5691c47e3108dde6ce    Station AVIA -B2M SARL
# 3      88f0da50efd15698a4f95f8f41f9937e         ESSO DE NORMANDIE
# 4      6ffa92232c2b53a39c2e9c72ca3429d4               GARAGE CARD
# ...                                 ...                       ...
# 43779  53d7d08694cd5b0aaadff973480fcc92           Maylands Garage
# 43780  669aebbe9617550891329c7a68e7d0f4  Universe Service Station
# 43781  0b6baa2ee62951cbb22398d9df2b0b43          Poole's Of Moira
# 43782  60fd484757775d4ca4384991fd3cfe14      Morrisons Hartcliffe
# 43783  ebd5e72ae555529a8bd771aa56aa3af4   Mitcham Road Sf Connect
#
#                                          station_address              Street  \
# 0          Autoroute A16 péage le touquet, 62630 Étaples
# 1      SA BRIODIS Centre Commercial du Carpont, 22440...
# 2                 Avenue Ernest Subilia, 13600 LA CIOTAT
# 3                    2 Route de Normandie, 80480 Salouël
# 4      20 Rue de Paris, 39150 Saint-Laurent-en-Grandvaux  Rue des Tisserands
# ...                                                  ...                 ...
# 43779                   28 Steeple Road, Mayland CM3 6BB                 NaN
# 43780            2165 Paisley Road West, Glasgow G52 3PF                 NaN
# 43781                     15 Main Street, Moira BT67 0LE                 NaN
# 43782            Peterson Avenue, City of Bristol BS13 0                 NaN
# 43783                    3 Mitcham Road, Croydon CR0 3RU                 NaN
#
#              City Postcode    Latitude  Longitude  Place_id Country
# 0                                                            France
# 1                                                            France
# 2                                                            France
# 3                                                            France
# 4      Hilsenheim    67600  48.2812644  7.5547576  75854100  France
# ...           ...      ...         ...        ...       ...     ...
# 43779         NaN      NaN         NaN        NaN       NaN     NaN
# 43780         NaN      NaN         NaN        NaN       NaN     NaN
# 43781         NaN      NaN         NaN        NaN       NaN     NaN
# 43782         NaN      NaN         NaN        NaN       NaN     NaN
# 43783         NaN      NaN         NaN        NaN       NaN     NaN
#
# [43784 rows x 10 columns]

# %%
final_df.head(2)
# Out:
#                                  id          station_name  \
# 0  b7be2e50cb1d5e7b8335e9e6dc6d25e8                 SHELL
# 1  55f54ad09d895c258131ad436b087980  E.LECLERC PLOUFRAGAN
#
#                                      station_address Street City Postcode  \
# 0      Autoroute A16 péage le touquet, 62630 Étaples
# 1  SA BRIODIS Centre Commercial du Carpont, 22440...
#
#   Latitude Longitude Place_id Country
# 0                              France
# 1                              France

# %%
bckup_final_df = final_df.copy()
bckup_final_df1 = final_df.copy()

# %%
bckup_final_df1.head(10)
# Out:
#                                  id               station_name  \
# 0  b7be2e50cb1d5e7b8335e9e6dc6d25e8                      SHELL
# 1  55f54ad09d895c258131ad436b087980       E.LECLERC PLOUFRAGAN
# 2  2a9b0401ff9d5f5691c47e3108dde6ce     Station AVIA -B2M SARL
# 3  88f0da50efd15698a4f95f8f41f9937e          ESSO DE NORMANDIE
# 4  6ffa92232c2b53a39c2e9c72ca3429d4                GARAGE CARD
# 5  ccc3b899f01b5f3aaa773f5df391f045         CASINO SUPERMARCHE
# 6  8e6f37157857581aa8b9f0e1ab596781           Carrefour Market
# 7  1293f4b928f25f8e8f12829c9afac212  EOR SAINTRY GGE DES BROSS
# 8  25ba9997cde753999cc4d8320cbc8773                          ⛽
# 9  f927277d281c5c89b74dcc42bf17e9d1                INTERMARCHE
#
#                                      station_address  \
# 0      Autoroute A16 péage le touquet, 62630 Étaples
# 1  SA BRIODIS Centre Commercial du Carpont, 22440...
# 2             Avenue Ernest Subilia, 13600 LA CIOTAT
# 3                2 Route de Normandie, 80480 Salouël
# 4  20 Rue de Paris, 39150 Saint-Laurent-en-Grandvaux
# 5            RN 8 Quartier le Charrel, 13400 AUBAGNE
# 6            Boulevard Auguste Comte, 24100 BERGERAC
# 7        183 Route de Melun, 91250 SAINTRY-SUR-SEINE
# 8      155 AVENUE PAUL DOUMER, 92500 Rueil-Malmaison
# 9                Rue du Général Leclerc, 52130 Wassy
#
#                      Street        City Postcode     Latitude  \
# 0
# 1
# 2
# 3
# 4        Rue des Tisserands  Hilsenheim    67600   48.2812644
# 5      Boulevard de Guizard    Espalion    12500   44.5235849
# 6  Boulevard de la Chapelle       Paris    75010  48.88367915
# 7
# 8
# 9      57 Route de Rouffach      Colmar    68000   48.0673483
#
#             Longitude   Place_id Country
# 0                                 France
# 1                                 France
# 2                                 France
# 3                                 France
# 4           7.5547576   75854100  France
# 5           2.7638757   44041847  France
# 6  2.3560908524463007  198541775  France
# 7                                 France
# 8                                 France
# 9            7.343814    5346274  France

# %%
save_data_new(final_df)
# Out:
# (snowflake.connector.errors.ProgrammingError) 001795 (42601): SQL compilation error: error line 1 at position 165
# maximum number of expressions in a list exceeded, expected at most 16,384, got 43,784
# [SQL: INSERT INTO "EXTERNAL_TABLES".viamichelin_stations (id, station_name, station_address, "Street", "City", "Postcode", "Latitude", "Longitude", "Place_id", "Country") VALUES (%(id)s, %(station_name)s, %(station_address)s, %(Street)s, %(City)s, %(Postcode)s, %(Latitude)s, %(Longitude)s, %(Place_id)s, %(Country)s)]
# [parameters: ({'id': 'b7be2e50cb1d5e7b8335e9e6dc6d25e8', 'station_name': 'SHELL', 'station_address': 'Autoroute A16 péage le touquet, 62630 Étaples', 'Street': '', 'City': '', 'Postcode': '', 'Latitude': '', 'Longitude': '', 'Place_id': '', 'Country': 'France'}, {'id': '55f54ad09d895c258131ad436b087980', 'station_name': 'E.LECLERC PLOUFRAGAN', 'station_address': 'SA BRIODIS Centre Commercial du Carpont, 22440 Ploufragan', 'Street': '', 'City': '', 'Postcode': '', 'Latitude': '', 'Longitude': '', 'Place_id': '', 'Country': 'France'}, {'id': '2a9b0401ff9d5f5691c47e3108dde6ce', 'station_name': 'Station AVIA -B2M SARL', 'station_address': 'Avenue Ernest Subilia, 13600 LA CIOTAT', 'Street': '', 'City': '', 'Postcode': '', 'Latitude': '', 'Longitude': '', 'Place_id': '', 'Country': 'France'}, {'id': '88f0da50efd15698a4f95f8f41f9937e', 'station_name': 'ESSO DE NORMANDIE', 'station_address': '2 Route de Normandie, 80480 Salouël', 'Street': '', 'City': '', 'Postcode': '', 'Latitude': '', 'Longitude': '', 'Place_id': '', 'Country': 'France'}, {'id': '6ffa92232c2b53a39c2e9c72ca3429d4', 'station_name': 'GARAGE CARD', 'station_address': '20 Rue de Paris, 39150 Saint-Laurent-en-Grandvaux', 'Street': 'Rue des Tisserands', 'City': 'Hilsenheim', 'Postcode': '67600', 'Latitude': '48.2812644', 'Longitude': '7.5547576', 'Place_id': '75854100', 'Country': 'France'}, {'id': 'ccc3b899f01b5f3aaa773f5df391f045', 'station_name': 'CASINO SUPERMARCHE', 'station_address': 'RN 8 Quartier le Charrel, 13400 AUBAGNE', 'Street': 'Boulevard de Guizard', 'City': 'Espalion', 'Postcode': '12500', 'Latitude': '44.5235849', 'Longitude': '2.7638757', 'Place_id': '44041847', 'Country': 'France'}, {'id': '8e6f37157857581aa8b9f0e1ab596781', 'station_name': 'Carrefour Market', 'station_address': 'Boulevard Auguste Comte, 24100 BERGERAC', 'Street': 'Boulevard de la Chapelle', 'City': 'Paris', 'Postcode': '75010', 'Latitude': '48.88367915', 'Longitude': '2.3560908524463007', 'Place_id': '198541775', 'Country': 'France'}, {'id': '1293f4b928f25f8e8f12829c9afac212', 'station_name': 'EOR SAINTRY GGE DES BROSS', 'station_address': '183 Route de Melun, 91250 SAINTRY-SUR-SEINE', 'Street': '', 'City': '', 'Postcode': '', 'Latitude': '', 'Longitude': '', 'Place_id': '', 'Country': 'France'}  ... displaying 10 of 43784 total bound parameter sets ...  {'id': '60fd484757775d4ca4384991fd3cfe14', 'station_name': 'Morrisons Hartcliffe', 'station_address': 'Peterson Avenue, City of Bristol BS13 0', 'Street': None, 'City': None, 'Postcode': None, 'Latitude': None, 'Longitude': None, 'Place_id': None, 'Country': None}, {'id': 'ebd5e72ae555529a8bd771aa56aa3af4', 'station_name': 'Mitcham Road Sf Connect', 'station_address': '3 Mitcham Road, Croydon CR0 3RU', 'Street': None, 'City': None, 'Postcode': None, 'Latitude': None, 'Longitude': None, 'Place_id': None, 'Country': None})]
# (Background on this error at: https://sqlalche.me/e/14/f405)

# %%
len(final_df)
# Out:
# 43784

# %%
div = 16000

# %%
save_data_new(final_df.iloc[:div])
# Out:
# id                              b7be2e50cb1d5e7b8335e9e6dc6d25e8
# station_name                                               SHELL
# station_address    Autoroute A16 péage le touquet, 62630 Étaples
# Street
# City
# Postcode
# Latitude
# Longitude
# Place_id
# Country                                                   France
# Name: 0, dtype: object

# %%
final_df.iloc[:div]
# Out:
#                                   id               station_name  \
# 0   b7be2e50cb1d5e7b8335e9e6dc6d25e8                      SHELL
# 1   55f54ad09d895c258131ad436b087980       E.LECLERC PLOUFRAGAN
# 2   2a9b0401ff9d5f5691c47e3108dde6ce     Station AVIA -B2M SARL
# 3   88f0da50efd15698a4f95f8f41f9937e          ESSO DE NORMANDIE
# 4   6ffa92232c2b53a39c2e9c72ca3429d4                GARAGE CARD
# 5   ccc3b899f01b5f3aaa773f5df391f045         CASINO SUPERMARCHE
# 6   8e6f37157857581aa8b9f0e1ab596781           Carrefour Market
# 7   1293f4b928f25f8e8f12829c9afac212  EOR SAINTRY GGE DES BROSS
# 8   25ba9997cde753999cc4d8320cbc8773                          ⛽
# 9   f927277d281c5c89b74dcc42bf17e9d1                INTERMARCHE
# 10  c07d5c4ee4d65aa4bb30d9fb8a4f9952     STATION ELAN POMPIGNAN
# 11  61fbf3bf78df5743b884d4fe36c58ccc               SUPER U BRUZ
#
#                                       station_address  \
# 0       Autoroute A16 péage le touquet, 62630 Étaples
# 1   SA BRIODIS Centre Commercial du Carpont, 22440...
# 2              Avenue Ernest Subilia, 13600 LA CIOTAT
# 3                 2 Route de Normandie, 80480 Salouël
# 4   20 Rue de Paris, 39150 Saint-Laurent-en-Grandvaux
# 5             RN 8 Quartier le Charrel, 13400 AUBAGNE
# 6             Boulevard Auguste Comte, 24100 BERGERAC
# 7         183 Route de Melun, 91250 SAINTRY-SUR-SEINE
# 8       155 AVENUE PAUL DOUMER, 92500 Rueil-Malmaison
# 9                 Rue du Général Leclerc, 52130 Wassy
# 10             190 ROUTE DE TOULOUSE, 82170 POMPIGNAN
# 11            109 Avenue Alphonse LEGAULT, 35170 BRUZ
#
#                       Street        City Postcode     Latitude  \
# 0
# 1
# 2
# 3
# 4         Rue des Tisserands  Hilsenheim    67600   48.2812644
# 5       Boulevard de Guizard    Espalion    12500   44.5235849
# 6   Boulevard de la Chapelle       Paris    75010  48.88367915
# 7
# 8
# 9       57 Route de Rouffach      Colmar    68000   48.0673483
# 10                       NaN         NaN      NaN          NaN
# 11                       NaN         NaN      NaN          NaN
#
#              Longitude   Place_id Country
# 0                                  France
# 1                                  France
# 2                                  France
# 3                                  France
# 4            7.5547576   75854100  France
# 5            2.7638757   44041847  France
# 6   2.3560908524463007  198541775  France
# 7                                  France
# 8                                  France
# 9             7.343814    5346274  France
# 10                 NaN        NaN     NaN
# 11                 NaN        NaN     NaN

# %%
# %%time
save_data_new(final_df.iloc[div:div*2])
# Out:
# 0
# CPU times: user 693 ms, sys: 18.7 ms, total: 711 ms
# Wall time: 7.98 s

# %%
final_df.iloc[div:div*2]
# Out:
#                                   id                          station_name  \
# 12  6db35eaf605a5cedad0064c4c3351ece                     RELAIS DE BOSSUET
# 13  567fde66041c5e8680f483a5e48bab3d                      EOR MAGESCQ MORA
# 14  b4019aa822a6549d85d9df2d30065285                 HONFLEUR-DISTRIBUTION
# 15  44d20bc8abdd587eaca3a94c7965f5ad                           SIGESS ESSO
# 16  d0967f8bb9cf57799a9b878099b2e32b                                 NETTO
# 17  636bcf64d5965e1f8ca85928ab8af006                AGIP LA MOTTE SERVOLEX
# 18  060a03930e395ef58b3270a8d0d46621                            SARL DAUDE
# 19  1939b03fc29851758768949494398e49                               SUPER U
# 20  07f5227d684b5236b8072f8d3e57309d                         Super U JANZE
# 21  ed13dd24fc8e5b7dbe403f094fa5abed  Carrefour market Saulx les chartreux
# 22  912b699617405eabae185cbae8c742ac        Carrefour contact saint aulaye
# 23  872ac568e99b59d2ba6e35a22881321f            RELAIS ST ETIENNE MASSENET
#
#                                       station_address Street City Postcode  \
# 12      1-5 AVENUE DE MELUN, 77100 Nanteuil-lès-Meaux    NaN  NaN      NaN
# 13                    Rue Robert Dubaa, 40140 MAGESCQ    NaN  NaN      NaN
# 14        Zone Industrielle Portuaire, 14600 Honfleur    NaN  NaN      NaN
# 15    8 avenue du 8 mai 1945, 77176 SAVIGNY-LE-TEMPLE    NaN  NaN      NaN
# 16        Le Parc des VERCHERES, 42450 Sury-le-Comtal    NaN  NaN      NaN
# 17   330 avenue JEAN ROSTAND, 73290 La Motte-Servolex    NaN  NaN      NaN
# 18                        AV DE LA GARE, 48230 Chanac    NaN  NaN      NaN
# 19            Route de Vallon Pont d'Arc, 07120 RUOMS    NaN  NaN      NaN
# 20                     BOULEVARD CHARCOT, 35150 Janzé    NaN  NaN      NaN
# 21      1 rue du pont neuf, 91160 Saulx-les-Chartreux    NaN  NaN      NaN
# 22  229 les grand champs, 24410 saint aulaye puyma...    NaN  NaN      NaN
# 23               11 AV DE VERDUN, 42000 Saint-Étienne    NaN  NaN      NaN
#
#    Latitude Longitude Place_id Country
# 12      NaN       NaN      NaN     NaN
# 13      NaN       NaN      NaN     NaN
# 14      NaN       NaN      NaN     NaN
# 15      NaN       NaN      NaN     NaN
# 16      NaN       NaN      NaN     NaN
# 17      NaN       NaN      NaN     NaN
# 18      NaN       NaN      NaN     NaN
# 19      NaN       NaN      NaN     NaN
# 20      NaN       NaN      NaN     NaN
# 21      NaN       NaN      NaN     NaN
# 22      NaN       NaN      NaN     NaN
# 23      NaN       NaN      NaN     NaN

# %%
save_data_new(final_df.iloc[div*2:div*3])
# Out:
# 0

# %%
len(final_df.iloc[div*2:div*3])
# Out:
# 11784

# %%
len(final_df)
# Out:
# 43784

# %%
final_df.iloc[div*2:div*3]
# Out:
#                                      id              station_name  \
# 32000  1632514e407e5efbbb05d9a309f14621                    REPSOL
# 32001  f38c57887b3e51838f9fffcc80bfd13f                      GALP
# 32002  2b1ea8f325a95d4491f2df8abac8f319              BP VALLESECO
# 32003  aa6b5d37c17d54fb98ed7d1effbdcb61                E.S. ALEDO
# 32004  2b47b152f5925a829418b178f89b707b                      ARGI
# ...                                 ...                       ...
# 43779  53d7d08694cd5b0aaadff973480fcc92           Maylands Garage
# 43780  669aebbe9617550891329c7a68e7d0f4  Universe Service Station
# 43781  0b6baa2ee62951cbb22398d9df2b0b43          Poole's Of Moira
# 43782  60fd484757775d4ca4384991fd3cfe14      Morrisons Hartcliffe
# 43783  ebd5e72ae555529a8bd771aa56aa3af4   Mitcham Road Sf Connect
#
#                                    station_address Street City Postcode  \
# 32000         CARRETERA N-630 KM. 412, 37700 BEJAR    NaN  NaN      NaN
# 32001    CARRETERA DEL PALMAR KM. 69, 30010 MURCIA    NaN  NaN      NaN
# 32002            CALLE PEROJO, 19, 35340 VALLESECO    NaN  NaN      NaN
# 32003        CARRETERA C-21 KM. 0,400, 30859 ALEDO    NaN  NaN      NaN
# 32004  POL. COMARCA I, PARCELA D 25, 31160 ORCOYEN    NaN  NaN      NaN
# ...                                            ...    ...  ...      ...
# 43779             28 Steeple Road, Mayland CM3 6BB    NaN  NaN      NaN
# 43780      2165 Paisley Road West, Glasgow G52 3PF    NaN  NaN      NaN
# 43781               15 Main Street, Moira BT67 0LE    NaN  NaN      NaN
# 43782      Peterson Avenue, City of Bristol BS13 0    NaN  NaN      NaN
# 43783              3 Mitcham Road, Croydon CR0 3RU    NaN  NaN      NaN
#
#       Latitude Longitude Place_id Country
# 32000      NaN       NaN      NaN     NaN
# 32001      NaN       NaN      NaN     NaN
# 32002      NaN       NaN      NaN     NaN
# 32003      NaN       NaN      NaN     NaN
# 32004      NaN       NaN      NaN     NaN
# ...        ...       ...      ...     ...
# 43779      NaN       NaN      NaN     NaN
# 43780      NaN       NaN      NaN     NaN
# 43781      NaN       NaN      NaN     NaN
# 43782      NaN       NaN      NaN     NaN
# 43783      NaN       NaN      NaN     NaN
#
# [11784 rows x 10 columns]

# %%
# %%time
save_data(final_df)
# Out:
# (snowflake.connector.errors.ProgrammingError) 001795 (42601): SQL compilation error: error line 1 at position 45
# maximum number of expressions in a list exceeded, expected at most 16,384, got 43,784
# [SQL: DELETE FROM viamichelin_stations WHERE id IN ('b7be2e50cb1d5e7b8335e9e6dc6d25e8', '55f54ad09d895c258131ad436b087980', '2a9b0401ff9d5f5691c47e3108dde6ce', '88f0da50efd15698a4f95f8f41f9937e', '6ffa92232c2b53a39c2e9c72ca3429d4', 'ccc3b899f01b5f3aaa773f5df391f045', '8e6f37157857581aa8b9f0e1ab596781', '1293f4b928f25f8e8f12829c9afac212', '25ba9997cde753999cc4d8320cbc8773', 'f927277d281c5c89b74dcc42bf17e9d1', 'c07d5c4ee4d65aa4bb30d9fb8a4f9952', '61fbf3bf78df5743b884d4fe36c58ccc', '6db35eaf605a5cedad0064c4c3351ece', '567fde66041c5e8680f483a5e48bab3d', 'b4019aa822a6549d85d9df2d30065285', '44d20bc8abdd587eaca3a94c7965f5ad', 'd0967f8bb9cf57799a9b878099b2e32b', '636bcf64d5965e1f8ca85928ab8af006', '060a03930e395ef58b3270a8d0d46621', '1939b03fc29851758768949494398e49', '07f5227d684b5236b8072f8d3e57309d', 'ed13dd24fc8e5b7dbe403f094fa5abed', '912b699617405eabae185cbae8c742ac', '872ac568e99b59d2ba6e35a22881321f', 'cb2e685bcc205815b8b0ae151e508633', '979ef7c98d6e5840b023bba1c4973bb4', '50ec70ea5f09529ca671668a8615bfae', '76ee3622700154a197251a8f30671810', '7895abfdbe745e128bc3d698a29f8441', '96d74cdde68055769483b644d237e454', '9e68bc6fb9fb5382950dd26279abaf85', 'b601374727bd5a2894798980dbd19696', '39050b2f9c1f50feba9a4b529ebaeba4', 'c18b2c3cef4c5afa8844b1319e9ebcbc', '0798f9ac50905f6cae7ffb4a6c9039f6', '0d378c3354f25535b897f4e89acbbbed', '4c3e9fd9990e58ad88d2f08dbfaa5106', '8de2ea7722785cc88b85fe24fb3e4bc9', 'd67fe797a054506c9412fbcd8b3b6f49', 'ff85d28aff755b7db3e05eab48a3802f', 'd8e14e8f02085610aff3cc52aa99e8f0', 'd62e28e1a5be57d7a5bc2036e9f25267', '0ea1aafa72fa58ac839109715b61adee', '2008c4672ca656e5ad36f43bd7236cbd', 'de9ee063cb1150679cc8955e327ab22d', '484d2fb44d0c53d5b20d3e7485b9ae6d', '9147cac178c65d2589e16ceefb48e93f', '2523500f1610511c8461ae23776fc93d', '7343ec4917575e668f8cd6fed8db0c0e', 'ab7f905be7c951dbb6c11180cca70d64', 'b6b5fbfff9a85d3d870de7127ab21760', 'b5a1698a0d6f5678ac3ec679bbd1fe4a', '9093fab864c859eb86610e7452265fb5', '49ac3281cb7553eb880ec87059383c21', '69ab126796405022bf2582954a041f8d', '4a861bcd47465cdb9d0fed11d1bea3a7', '02889cdd4ea85a25b84480643f16c258', 'a088376643165f54a20da93c88428f91', 'a4bb178d9dac576293a9180c6194695e', 'de24661eac7458deb1c16fcaa7e14a4a', '3cfe81d961045030ae4f4b586e527d68', '65fc27b2ebfd52f085e0268ff44082d4', 'ab704439a22057f6a6e74aaebb4ff685', '8bc7f8e7f3ac5dffa517995ea28fc7b2', '7700108c335e583881ec1e5939a25289', 'd7d482ee6c145367a38b012b84ab0343', '45437f1817bc5bf2a4c208588d3c6b72', '92811fefda5a5267b6770d5a64a12f75', '79d49c832f7158e496a94c2c37ed169a', '8e1205bea5015b51a82900211dec8d77', 'c29541a3b1255effa4dec672f1804def', 'f43caf6c115852d1ba4edb00f4f30370', 'a3947e2d355d5f5ea1851386e6ba8e56', 'fa46c370b1da5fa1a73699752a6dc688', 'b7006afe42065cd39cf9adf0a2f4444e', '5bf1d02ef4825104b5a984a79be86dec', '1b7aa56a51685376847646061af98ba4', '768c8f401b455fffbee63a2679d10fbf', '141cf21d06145c6580769dcb0f816401', '8ec37c7d169350a497d336ad10402f9f', 'ff75513da2ea595aa011d6ca8b3f9b15', '3be9eab786d25cc1849418173e93095b', 'f0161357d10b5619b67928e4f651d509', '0e261ad0ae815811986632e08ae9694c', 'ca33fc18ef68537e84877606e40f4214', '344c277dc1145d7b8840a603addf51a4', 'a0eb71ef931d583998d2c8886c6e0ec9', 'f224306c0ff25387b0eaf88c2d5f7f9e', '194892b9e42253349e0ee444efdb416d', '9de26adf341f527e9bbcf90986841a08', '78dc008d53dc54f3912d6bc286df4c37', 'f8d923be2adb57a3b025af30552c4e8e', '212221666d6b51ca847e1d7b25f60d93', '4877a699bc3a51e0b808baf4fa8fcd92', 'dee264de65ef53fc9eb9955780678d0e', '5615991d27f058b381ba67aeddccdb4c', 'e1e0f334b5995dcb87335b35a4b94881', 'edc77bc986725b84bacf64fee7bb2541', '93ca28d2864c52d08fddd45e87afefd1', '39cf5724f9c350078652ae2f5f20e2fe', '7cf8baec093c5d8aab8436865111f93a', 'f5e073fa74dd58c09cd04c5ed57cbb6b', 'f729b02263d05f26a0e8807f32b3d518', '6623137495d85dbd8a7f7a3c5a745fe4', '1b8cd117ce58539d8bfba842787fc795', '79e5634749f6509297a4de0cd6552868', '0ea17e53f17551d1b931fce6a0105bea', '8640748ef78e52028e3db05e402e9ae6', '4d456b7ce1e25394a8cdc2c5376522eb', '6633d515f77a5547b69a238 ...
# (Background on this error at: https://sqlalche.me/e/14/f405)
# CPU times: user 524 ms, sys: 23.2 ms, total: 547 ms
# Wall time: 1.57 s

# %%
#!/usr/bin/env python3


import requests
from bs4 import BeautifulSoup
import pandas as pd
import uuid
import hashlib
from snowflake.sqlalchemy import URL
from sqlalchemy import create_engine
import json
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="viamichelin")


# Load the Snowflake configuration from the JSON file
with open("snow_cred.json") as f:
    config = json.load(f)
    
    
# Creating Snowflake Connection
snow_engine = create_engine(URL(
    account = config['account'],
    user = config['user'],
    password = config['password'],
    database = config['database'],
    schema = config['schema'],
    warehouse = config['warehouse'],
    role= config['role']
))

snow_connection = snow_engine.connect()
snow_connection


countries = ['France', 'United Kingdom', 'Switzerland', 'Germany', 'Belgium', 'Netherlands', 'Spain', 'Luxembourg', 'Czech Republic', 'Italy']
country_url_list = ['https://www.viamichelin.fr/web/Stations-service?address=France', 'https://www.viamichelin.fr/web/Stations-service?address=united%20kingdom', 'https://www.viamichelin.fr/web/Stations-service?address=switzerland', 'https://www.viamichelin.fr/web/Stations-service?address=germany', 'https://www.viamichelin.fr/web/Stations-service?address=Belgium', 'https://www.viamichelin.fr/web/Stations-service?address=netherlands', 'https://www.viamichelin.fr/web/Stations-service?address=spain', 'https://www.viamichelin.fr/web/Stations-service?address=luxemburg', 'https://www.viamichelin.fr/web/Stations-service?address=Czechia', 'https://www.viamichelin.fr/web/Stations-service?address=Italy']


def get_rqt(url):
    r = requests.get(url)
    sp = BeautifulSoup(r.content, 'html.parser')
    return sp


def get_pagi_url_max_num(page_n):
    pg = BeautifulSoup(str(page_n[0]), 'html.parser')
    pg_a = pg.findAll('a')

    if len(pg_a) > 0:
        pg_a = pg_a[-1]
        pgination_url = pg_a['href']
        pgination_url = pgination_url[0:pgination_url.index('=')+1]
        max_pg = int(pg_a.get_text())
        return pgination_url, max_pg
    
    
def get_pagination(url):
    r = requests.get(url)
    #print(r)
    soup = BeautifulSoup(r.content, 'html.parser')
    page_n = soup.findAll("p", class_="pagination-second-line")
    return page_n


def save_data(data_df):
    target_table = 'viamichelin_stations'
    del_id_lst = str(list(data_df['id'])).replace('[','(').replace(']',')') 
    try:
        # Delete existing rows to be updated with new version
        del_existing_rows_query = "DELETE FROM " +target_table+ " WHERE id IN " + del_id_lst
        #print('Del Query is ', del_existing_rows_query)
        with snow_engine.connect() as conn:
            conn.execute(del_existing_rows_query)

        # Save data in the DataFrame    
        data_df.to_sql(target_table, con=snow_engine, schema='EXTERNAL_TABLES', index=False, if_exists='append')
        print(data_df.loc[0])
        data_df = pd.DataFrame()
    except Exception as err:
        print(err)    
        
        
def get_street(address, station_address):
    if 'house_number' in address:
        if address['house_number'] in station_address.split():
            street = str(address['house_number']) + ' ' + str(address['road']) if 'road' in address else ''
        else:
            street = str(address['road']) if 'road' in address else ''
    else:
        street = str(address['road']) if 'road' in address else ''
        
    return street


def get_city(address):
    if 'city' in address:
        city = address['city']
    elif 'town' in address: 
        city = address['town']
    elif 'village' in address: 
        city = address['village']    
    else:
        city = ''
    return city



# Enrich Station Address
def split_address(station_address):
    enriched_address = []
    for i in station_address:
        new_station_address = []
        location = geolocator.geocode(i) # 18 Hauptstrasse, 3752 Wimmis
        #print(type(location))
        if location:
            #print(location.raw)
            lat = location.raw['lat']
            lon = location.raw['lon']
            location_geop = geolocator.reverse(f"{lat}, {lon}")
            address = location_geop.raw['address']
            postcode = str(address['postcode']) if 'postcode' in address else ''
            place_id = str(location_geop.raw['place_id']) if 'place_id' in location_geop.raw else ''
            station_street = get_street(address, i)
            station_city = get_city(address)
            #print(location_geop.raw)    
            new_station_address.extend([station_street, station_city, postcode, lat, lon, place_id])
            enriched_address.append(new_station_address)
        else:
            #print("Location not found")
            new_station_address.extend(['', '', '', '', '', ''])
            enriched_address.append(new_station_address)
    #print(type(enriched_address), '\nNow Appending enriched_address...')                    
    enriched_address_df = pd.DataFrame(enriched_address, columns = ['Street', 'City', 'Postcode', 'Latitude', 'Longitude', 'Place_id'])
    return enriched_address_df


    
def get_and_save_data(url, ctry):
    r = requests.get(url)
    print(ctry, url, r)
    soup = BeautifulSoup(r.content, 'html.parser')

    # Get station Names
    station_names = soup.findAll('div', class_='poi-item-name truncate')
    station_names = [val.get_text() for val in station_names]

    # Get station Addresses
    station_address = soup.findAll('div', class_="poi-item-details-address truncate")
    station_address = [val.get_text() for val in station_address]
    print(len(station_names), len(station_address))
    #print(station_names,'\n\n', station_address)

    # Combine the Scrapped data into a list ready to be converted into a DataFrame
    dat_zip = zip(station_names, station_address)

    zipped_dat = list(dat_zip)
    dat_zip = ''
    data = [list(i) for i in zipped_dat]
    zipped_dat.clear()
    
    # Clear the list to save memory        
    station_names.clear()
    station_address.clear()
    

    # Create DataFrame from the data list
    data_df = pd.DataFrame(data, columns=['Station_Name', 'Station_Address'])
    data.clear()

    # Generate a UUID for each row based on the values in 'Station_Name' and 'Station_Address'
    generate_uuid = lambda row: uuid.uuid5(uuid.NAMESPACE_DNS, str(row['Station_Name']) + str(row['Station_Address'])).hex
    
    # Enrich Station Address here
    enriched_address_df = split_address(list(data_df['Station_Address'])) 

    # Add new columns to the created DataFrame
    data_df['id'] = data_df.apply(generate_uuid, axis=1)

    # Rearrange DataFrame
    data_df = data_df[['id', 'Station_Name', 'Station_Address']]
    #print('Len data_fr -> ', len(data_df), 'Len enriched_address_df -> ', len(enriched_address_df))
    
    # Add the new DataFrame to the old one by concatenating the dataframes vertically
    data_df = pd.concat([data_df, enriched_address_df], axis=1)
    data_df["country"] = ctry
    
    #print('Len data_df -> ', len(data_df))
    # Save the Data to DB
    save_data(data_df)
    print('SAVED')

        

for url, ctry in zip(country_url_list, countries):
    try:
        # Scrape the page and save data
        get_and_save_data(url, ctry)        
        
        # Get and prepare Pagination        
        page_n = get_pagination(url)
        if get_pagi_url_max_num(page_n):
            #print('More')
            pgination_url, max_pg = get_pagi_url_max_num(page_n)
            for i in range(2, max_pg + 1):  # range(2, max_pg+1)
                get_and_save_data(pgination_url+str(i), ctry)
        else:
            #print('less')
            continue
        
    except Exception as err:
        print(err)
# Out:
# name 'max_pg' is not defined
# name 'max_pg' is not defined
# name 'max_pg' is not defined
# name 'max_pg' is not defined
# name 'max_pg' is not defined
# name 'max_pg' is not defined
# name 'max_pg' is not defined
# name 'max_pg' is not defined
# name 'max_pg' is not defined

# %%
#!/usr/bin/env python3


import requests
from bs4 import BeautifulSoup
import pandas as pd
import uuid
import hashlib
from snowflake.sqlalchemy import URL
from sqlalchemy import create_engine
import json
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="viamichelin")


# Load the Snowflake configuration from the JSON file
with open("snow_cred.json") as f:
    config = json.load(f)
    
    
# Creating Snowflake Connection
snow_engine = create_engine(URL(
    account = config['account'],
    user = config['user'],
    password = config['password'],
    database = config['database'],
    schema = config['schema'],
    warehouse = config['warehouse'],
    role= config['role']
))

snow_connection = snow_engine.connect()
snow_connection


countries = ['France', 'United Kingdom', 'Switzerland', 'Germany', 'Belgium', 'Netherlands', 'Spain', 'Luxembourg', 'Czech Republic', 'Italy']
country_url_list = ['https://www.viamichelin.fr/web/Stations-service?address=France', 'https://www.viamichelin.fr/web/Stations-service?address=united%20kingdom', 'https://www.viamichelin.fr/web/Stations-service?address=switzerland', 'https://www.viamichelin.fr/web/Stations-service?address=germany', 'https://www.viamichelin.fr/web/Stations-service?address=Belgium', 'https://www.viamichelin.fr/web/Stations-service?address=netherlands', 'https://www.viamichelin.fr/web/Stations-service?address=spain', 'https://www.viamichelin.fr/web/Stations-service?address=luxemburg', 'https://www.viamichelin.fr/web/Stations-service?address=Czechia', 'https://www.viamichelin.fr/web/Stations-service?address=Italy']


def get_rqt(url):
    r = requests.get(url)
    sp = BeautifulSoup(r.content, 'html.parser')
    return sp


def get_pagi_url_max_num(page_n):
    pg = BeautifulSoup(str(page_n[0]), 'html.parser')
    pg_a = pg.findAll('a')

    if len(pg_a) > 0:
        pg_a = pg_a[-1]
        pgination_url = pg_a['href']
        pgination_url = pgination_url[0:pgination_url.index('=')+1]
        max_pg = int(pg_a.get_text())
        return pgination_url, max_pg
    
    
def get_pagination(url):
    r = requests.get(url)
    #print(r)
    soup = BeautifulSoup(r.content, 'html.parser')
    page_n = soup.findAll("p", class_="pagination-second-line")
    return page_n


def save_data(data_df):
    target_table = 'viamichelin_stations'
    del_id_lst = str(list(data_df['id'])).replace('[','(').replace(']',')') 
    try:
        # Delete existing rows to be updated with new version
        del_existing_rows_query = "DELETE FROM " +target_table+ " WHERE id IN " + del_id_lst
        #print('Del Query is ', del_existing_rows_query)
        with snow_engine.connect() as conn:
            conn.execute(del_existing_rows_query)

        # Save data in the DataFrame    
        data_df.to_sql(target_table, con=snow_engine, schema='public', index=False, if_exists='append')
        print(data_df.loc[0])
        data_df = pd.DataFrame()
    except Exception as err:
        print(err)    


def get_street(address, station_address):
    if 'house_number' in address:
        print('Yes')
        if address['house_number'] in station_address.split():
            street = str(address['house_number']) + ' ' + str(address['road']) if 'road' in address else ''
        else:
            street = str(address['road']) if 'road' in address else ''
        print('Yes ', street)
    else:
        street = str(address['road']) if 'road' in address else ''
        
    return street


def get_city(address):
    if 'city' in address:
        city = address['city']
    elif 'town' in address: 
        city = address['town']
    elif 'village' in address: 
        city = address['village']    
    else:
        city = ''
    return city



# Enrich Station Address
def split_address(station_address):
    enriched_address = []
    for i in station_address:
        new_station_address = []
        location = geolocator.geocode(i) # 18 Hauptstrasse, 3752 Wimmis
        print(type(location))
        if location:
            print(location.raw)
            lat = location.raw['lat']
            lon = location.raw['lon']
            location_geop = geolocator.reverse(f"{lat}, {lon}")
            address = location_geop.raw['address']
            postcode = str(address['postcode']) if 'postcode' in address else ''
            place_id = str(location_geop.raw['place_id']) if 'place_id' in location_geop.raw else ''
            station_street = get_street(address, i)
            station_city = get_city(address)
            #print(location_geop.raw)    
            new_station_address.extend([station_street, station_city, postcode, lat, lon, place_id])
        else:
            print("Location not found")
            new_station_address.extend(['', '', '', '', '', ''])
    print(type(enriched_address), '\nNow Appending enriched_address...')                
    enriched_address.append(new_station_address)
    enriched_address_df = pd.DataFrame(enriched_address, columns = ['Street', 'City', 'Postcode', 'Latitude', 'Longitude', 'Place_id'])
    return enriched_address_df



    
def get_and_save_data(url, ctry):
    r = requests.get(url)
    print(ctry, url, r)
    soup = BeautifulSoup(r.content, 'html.parser')

    # Get station Names
    station_names = soup.findAll('div', class_='poi-item-name truncate')
    station_names = [val.get_text() for val in station_names]

    # Get station Addresses
    station_address = soup.findAll('div', class_="poi-item-details-address truncate")
    station_address = [val.get_text() for val in station_address]
    print(len(station_names), len(station_address))
    #print(station_names,'\n\n', station_address)

    # Combine the Scrapped data into a list ready to be converted into a DataFrame
    dat_zip = zip(station_names[:10], station_address[:10])

    zipped_dat = list(dat_zip)
    dat_zip = ''
    data = [list(i) for i in zipped_dat]
    zipped_dat.clear()
    
    # Clear the list to save memory        
    station_names.clear()
    station_address.clear()
    

    # Create DataFrame from the data list
    data_df = pd.DataFrame(data, columns=['Station_Name', 'Station_Address'])
    data.clear()

    # Generate a UUID for each row based on the values in 'Station_Name' and 'Station_Address'
    generate_uuid = lambda row: uuid.uuid5(uuid.NAMESPACE_DNS, str(row['Station_Name']) + str(row['Station_Address'])).hex
    
    # Enrich Station Address here
    enriched_address_df = split_address(list(data_df['Station_Address']))        

    # Add new columns to the created DataFrame    
    data_df['id'] = data_df.apply(generate_uuid, axis=1)

    #Rearrange DataFrame
    data_df = data_df[['id', 'Station_Name', 'Station_Address']]
    
    # Add the new DataFrame to the old one by concatenating the dataframes vertically
    data_df = pd.concat([data_df, enriched_address_df])
    data_df["country"] = ctry
    
    print('DataFrame to SAVE\n\n',data_df.head(5))
    
    # Save the Data to DB
    save_data(data_df)

        

for url, ctry in zip(country_url_list, countries):
    try:
        # Scrape the page and save data
        get_and_save_data(url, ctry)        
        
        # Get and prepare Pagination        
        page_n = get_pagination(url)
        if get_pagi_url_max_num(page_n):
            print('More')
            pgination_url, max_pg = get_pagi_url_max_num(page_n)
            for i in range(2, max_pg + 1):  # range(2, max_pg+1)
                get_and_save_data(pgination_url+str(i), ctry)
        else:
            print('less')
            continue
        
    except Exception as err:
        print(err)
# Out:
# France https://www.viamichelin.fr/web/Stations-service?address=France <Response [200]>
# 48 48
# <class 'NoneType'>
# Location not found
# <class 'NoneType'>
# Location not found
# <class 'NoneType'>
# Location not found
# <class 'geopy.location.Location'>
# {'place_id': 100363813, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'way', 'osm_id': 4710350, 'boundingbox': ['48.8349979', '48.8353329', '-1.2192066', '-1.2187055'], 'lat': '48.8350853', 'lon': '-1.2187997', 'display_name': 'Route de Vire, La Croix au Grand, Villedieu-les-Poêles, Villedieu-les-Poêles-Rouffigny, Saint-Lô, Manche, Normandie, France métropolitaine, 50800, France', 'class': 'highway', 'type': 'primary', 'importance': 0.6000099999999999}
# <class 'geopy.location.Location'>
# {'place_id': 278455470, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'way', 'osm_id': 925966642, 'boundingbox': ['43.6879612', '43.6880001', '4.2731883', '4.2732285'], 'lat': '43.6879925', 'lon': '4.2732199', 'display_name': 'Avenue de la Condamine, Lotissement La Vallée Verte, Vauvert, Nîmes, Gard, Occitanie, France métropolitaine, 30600, France', 'class': 'highway', 'type': 'tertiary', 'importance': 0.71}
# <class 'NoneType'>
# Location not found
# <class 'NoneType'>
# Location not found
# <class 'geopy.location.Location'>
# {'place_id': 227882806, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'way', 'osm_id': 591318180, 'boundingbox': ['49.1113684', '49.1723649', '4.1705646', '4.2520204'], 'lat': '49.1435785', 'lon': '4.2131443', 'display_name': 'Autoroute de l’Est, Val-de-Vesle, Reims, Marne, Grand Est, France métropolitaine, 51360, France', 'class': 'highway', 'type': 'motorway', 'importance': 0.50001}
# <class 'NoneType'>
# Location not found
# <class 'geopy.location.Location'>
# {'place_id': 3442602, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'node', 'osm_id': 442366814, 'boundingbox': ['48.9932865', '48.9933865', '1.6289813', '1.6290813'], 'lat': '48.9933365', 'lon': '1.6290313', 'display_name': 'Aire Sud de Rosny-sur-Seine, Autoroute de Normandie, Rosny-sur-Seine, Mantes-la-Jolie, Yvelines, Île-de-France, France métropolitaine, 78710, France', 'class': 'highway', 'type': 'motorway_junction', 'importance': 0.8101}
# <class 'list'>
# Now Appending enriched_address...
# DataFrame to SAVE
#
#                                   id                 Station_Name  \
# 0  c3bc917a0526548182794c231af48ceb  RELAIS ST GERMAIN L ARPAJON
# 1  591a9af89eb955549869407ed54cc85f             RELAIS BACONNETS
# 2  65213a967a835a6b8d8ae7d66cd2ef34                RELAIS VELIZY
# 3  2392873b80645709b79ebc7afaf057f0             CARREFOUR Market
# 4  fba837ca6eff525a8f39dfea4f4bf981             Carrefour Market
#
#                                      Station_Address Street City Postcode  \
# 0  25 ROUTE D'ORLEANS RN 20, 91180 Saint-Germain-...    NaN  NaN      NaN
# 1          100 AV DU PRESIDENT KENNEDY, 92160 ANTONY    NaN  NaN      NaN
# 2  AUTOROUTE A86 - AIRE DE VELIZY OUEST, 78140 Vé...    NaN  NaN      NaN
# 3                      route de vire, 50000 Saint-Lô    NaN  NaN      NaN
# 4              Avenue de la Condamine, 30600 VAUVERT    NaN  NaN      NaN
#
#   Latitude Longitude Place_id country
# 0      NaN       NaN      NaN  France
# 1      NaN       NaN      NaN  France
# 2      NaN       NaN      NaN  France
# 3      NaN       NaN      NaN  France
# 4      NaN       NaN      NaN  France
# (snowflake.connector.errors.ProgrammingError) 000904 (42000): SQL compilation error: error line 1 at position 406
# invalid identifier 'NAN'
# [SQL: DELETE FROM viamichelin_stations WHERE id IN ('c3bc917a0526548182794c231af48ceb', '591a9af89eb955549869407ed54cc85f', '65213a967a835a6b8d8ae7d66cd2ef34', '2392873b80645709b79ebc7afaf057f0', 'fba837ca6eff525a8f39dfea4f4bf981', 'b88cb4ee073457e88d3b7bfebb8c5cdf', '0e226255f7895ae78815914338a2682f', '5513080bfb935bedadd314f12843f941', '6c6c7454003b55178e8ce2a9eef741b6', 'ad613332db65565288cfad42ae9e0920', nan)]
# (Background on this error at: https://sqlalche.me/e/14/f405)
# More
# France https://www.viamichelin.fr/web/Stations-service/Stations-service-France?page=2 <Response [200]>
# 48 48
# <class 'geopy.location.Location'>
# {'place_id': 183104967, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'way', 'osm_id': 323599797, 'boundingbox': ['50.652339', '50.6552534', '2.837552', '2.8420995'], 'lat': '50.6540527', 'lon': '2.8399556', 'display_name': 'Rue des Glattignies, Fleurbaix, Béthune, Pas-de-Calais, Hauts-de-France, France métropolitaine, 62840, France', 'class': 'highway', 'type': 'secondary', 'importance': 0.6200099999999998}
# <class 'NoneType'>
# Location not found
# <class 'geopy.location.Location'>
# {'place_id': 116745119, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'way', 'osm_id': 40108349, 'boundingbox': ['43.9892243', '43.9921154', '1.3307643', '1.3335824'], 'lat': '43.9905381', 'lon': '1.3317842', 'display_name': "Avenue de l'Europe, Albasud, Montauban, Tarn-et-Garonne, Occitanie, France métropolitaine, 82000, France", 'class': 'highway', 'type': 'tertiary', 'importance': 0.71}
# <class 'geopy.location.Location'>
# {'place_id': 41545555, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'node', 'osm_id': 3286282647, 'boundingbox': ['48.8449142', '48.8450142', '2.2714665', '2.2715665'], 'lat': '48.8449642', 'lon': '2.2715165', 'display_name': "BP, 99, Avenue de Versailles, Quartier d'Auteuil, Paris 16e Arrondissement, Paris, Île-de-France, France métropolitaine, 75016, France", 'class': 'amenity', 'type': 'fuel', 'importance': 0.6300999999999999, 'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/transport_fuel.p.20.png'}
# <class 'geopy.location.Location'>
# {'place_id': 124450711, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'way', 'osm_id': 86627878, 'boundingbox': ['50.0593323', '50.0598491', '1.8971493', '1.8978654'], 'lat': '50.0598196', 'lon': '1.8971902', 'display_name': 'Rue Jean Moulin, Pont-Remy, Abbeville, Somme, Hauts-de-France, France métropolitaine, 80580, France', 'class': 'highway', 'type': 'primary', 'importance': 0.71}
# <class 'NoneType'>
# Location not found
# <class 'NoneType'>
# Location not found
# <class 'NoneType'>
# Location not found
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [12], in <cell line: 196>()
#     205     pgination_url, max_pg = get_pagi_url_max_num(page_n)
#     206     for i in range(2, max_pg + 1):  # range(2, max_pg+1)
# --> 207         get_and_save_data(pgination_url+str(i), ctry)
#     208 else:
#     209     print('less')
#
# Input In [12], in get_and_save_data(url, ctry)
#     174 generate_uuid = lambda row: uuid.uuid5(uuid.NAMESPACE_DNS, str(row['Station_Name']) + str(row['Station_Address'])).hex
#     176 # Enrich Station Address here
# --> 177 enriched_address_df = split_address(list(data_df['Station_Address']))
#     179 # Add new columns to the created DataFrame
#     180 data_df['id'] = data_df.apply(generate_uuid, axis=1)
#
# Input In [12], in split_address(station_address)
#     114 for i in station_address:
#     115     new_station_address = []
# --> 116     location = geolocator.geocode(i) # 18 Hauptstrasse, 3752 Wimmis
#     117     print(type(location))
#     118     if location:
#
# File ~/opt/anaconda3/envs/route_env/lib/python3.10/site-packages/geopy/geocoders/nominatim.py:297, in Nominatim.geocode(self, query, exactly_one, timeout, limit, addressdetails, language, geometry, extratags, country_codes, viewbox, bounded, featuretype, namedetails)
#     295 logger.debug("%s.geocode: %s", self.__class__.__name__, url)
#     296 callback = partial(self._parse_json, exactly_one=exactly_one)
# --> 297 return self._call_geocoder(url, callback, timeout=timeout)
#
# File ~/opt/anaconda3/envs/route_env/lib/python3.10/site-packages/geopy/geocoders/base.py:368, in Geocoder._call_geocoder(self, url, callback, timeout, is_json, headers)
#     366 try:
#     367     if is_json:
# --> 368         result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#     369     else:
#     370         result = self.adapter.get_text(url, timeout=timeout, headers=req_headers)
#
# File ~/opt/anaconda3/envs/route_env/lib/python3.10/site-packages/geopy/adapters.py:438, in RequestsAdapter.get_json(self, url, timeout, headers)
#     437 def get_json(self, url, *, timeout, headers):
# --> 438     resp = self._request(url, timeout=timeout, headers=headers)
#     439     try:
#     440         return resp.json()
#
# File ~/opt/anaconda3/envs/route_env/lib/python3.10/site-packages/geopy/adapters.py:448, in RequestsAdapter._request(self, url, timeout, headers)
#     446 def _request(self, url, *, timeout, headers):
#     447     try:
# --> 448         resp = self.session.get(url, timeout=timeout, headers=headers)
#     449     except Exception as error:
#     450         message = str(error)
#
# File ~/opt/anaconda3/envs/route_env/lib/python3.10/site-packages/requests/sessions.py:600, in Session.get(self, url, **kwargs)
#     592 r"""Sends a GET request. Returns :class:`Response` object.
#     593
#     594 :param url: URL for the new :class:`Request` object.
#     595 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     596 :rtype: requests.Response
#     597 """
#     599 kwargs.setdefault("allow_redirects", True)
# --> 600 return self.request("GET", url, **kwargs)
#
# File ~/opt/anaconda3/envs/route_env/lib/python3.10/site-packages/requests/sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~/opt/anaconda3/envs/route_env/lib/python3.10/site-packages/requests/sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File ~/opt/anaconda3/envs/route_env/lib/python3.10/site-packages/requests/adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     487 try:
#     488     if not chunked:
# --> 489         resp = conn.urlopen(
#     490             method=request.method,
#     491             url=url,
#     492             body=request.body,
#     493             headers=request.headers,
#     494             redirect=False,
#     495             assert_same_host=False,
#     496             preload_content=False,
#     497             decode_content=False,
#     498             retries=self.max_retries,
#     499             timeout=timeout,
#     500         )
#     502     # Send the request.
#     503     else:
#     504         if hasattr(conn, "proxy_pool"):
#
# File ~/opt/anaconda3/envs/route_env/lib/python3.10/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File ~/opt/anaconda3/envs/route_env/lib/python3.10/site-packages/urllib3/connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~/opt/anaconda3/envs/route_env/lib/python3.10/site-packages/urllib3/connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File ~/opt/anaconda3/envs/route_env/lib/python3.10/http/client.py:1374, in HTTPConnection.getresponse(self)
#    1372 try:
#    1373     try:
# -> 1374         response.begin()
#    1375     except ConnectionError:
#    1376         self.close()
#
# File ~/opt/anaconda3/envs/route_env/lib/python3.10/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File ~/opt/anaconda3/envs/route_env/lib/python3.10/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File ~/opt/anaconda3/envs/route_env/lib/python3.10/socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File ~/opt/anaconda3/envs/route_env/lib/python3.10/ssl.py:1274, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1270     if flags != 0:
#    1271         raise ValueError(
#    1272           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1273           self.__class__)
# -> 1274     return self.read(nbytes, buffer)
#    1275 else:
#    1276     return super().recv_into(buffer, nbytes, flags)
#
# File ~/opt/anaconda3/envs/route_env/lib/python3.10/ssl.py:1130, in SSLSocket.read(self, len, buffer)
#    1128 try:
#    1129     if buffer is not None:
# -> 1130         return self._sslobj.read(len, buffer)
#    1131     else:
#    1132         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
#!/usr/bin/env python3


import requests
from bs4 import BeautifulSoup
import pandas as pd
import uuid
import hashlib
from snowflake.sqlalchemy import URL
from sqlalchemy import create_engine
import json



# Load the Snowflake configuration from the JSON file
with open("snow_cred.json") as f:
    config = json.load(f)
    
    
# Creating Snowflake Connection
snow_engine = create_engine(URL(
    account = config['account'],
    user = config['user'],
    password = config['password'],
    database = config['database'],
    schema = config['schema'],
    warehouse = config['warehouse'],
    role= config['role']
))

snow_connection = snow_engine.connect()
snow_connection


countries = ['France', 'United Kingdom', 'Switzerland', 'Germany', 'Belgium', 'Netherlands', 'Spain', 'Luxembourg', 'Czech Republic', 'Italy']
country_url_list = ['https://www.viamichelin.fr/web/Stations-service?address=France', 'https://www.viamichelin.fr/web/Stations-service?address=united%20kingdom', 'https://www.viamichelin.fr/web/Stations-service?address=switzerland', 'https://www.viamichelin.fr/web/Stations-service?address=germany', 'https://www.viamichelin.fr/web/Stations-service?address=Belgium', 'https://www.viamichelin.fr/web/Stations-service?address=netherlands', 'https://www.viamichelin.fr/web/Stations-service?address=spain', 'https://www.viamichelin.fr/web/Stations-service?address=luxemburg', 'https://www.viamichelin.fr/web/Stations-service?address=Czechia', 'https://www.viamichelin.fr/web/Stations-service?address=Italy']


def get_rqt(url):
    r = requests.get(url)
    sp = BeautifulSoup(r.content, 'html.parser')
    return sp


def get_pagi_url_max_num(page_n):
    pg = BeautifulSoup(str(page_n[0]), 'html.parser')
    pg_a = pg.findAll('a')

    if len(pg_a) > 0:
        pg_a = pg_a[-1]
        pgination_url = pg_a['href']
        pgination_url = pgination_url[0:pgination_url.index('=')+1]
        max_pg = int(pg_a.get_text())
        return pgination_url, max_pg
    
    
def get_pagination(url):
    r = requests.get(url)
    #print(r)
    soup = BeautifulSoup(r.content, 'html.parser')
    page_n = soup.findAll("p", class_="pagination-second-line")
    return page_n


def save_data(data_df):
    target_table = 'viamichelin_stations'
    del_id_lst = str(list(data_df['id'])).replace('[','(').replace(']',')') 
    try:
        # Delete existing rows to be updated with new version
        del_existing_rows_query = "DELETE FROM " +target_table+ " WHERE id IN " + del_id_lst
        #print('Del Query is ', del_existing_rows_query)
        with snow_engine.connect() as conn:
            conn.execute(del_existing_rows_query)

        # Save data in the DataFrame    
        data_df.to_sql(target_table, con=snow_engine, schema='public', index=False, if_exists='append')
        print(data_df.loc[0])
        data_df = pd.DataFrame()
    except Exception as err:
        print(err)    

    
def get_and_save_data(url, ctry):
    r = requests.get(url)
    print(ctry, url, r)
    soup = BeautifulSoup(r.content, 'html.parser')

    # Get station Names
    station_names = soup.findAll('div', class_='poi-item-name truncate')
    station_names = [val.get_text() for val in station_names]

    # Get station Addresses
    station_address = soup.findAll('div', class_="poi-item-details-address truncate")
    station_address = [val.get_text() for val in station_address]
    print(len(station_names), len(station_address))
    #print(station_names,'\n\n', station_address)

    # Combine the Scrapped data into a list ready to be converted into a DataFrame
    dat_zip = zip(station_names, station_address)

    zipped_dat = list(dat_zip)
    dat_zip = ''
    data = [list(i) for i in zipped_dat]
    zipped_dat.clear()
    
    # Clear the list to save memory        
    station_names.clear()
    station_address.clear()
    

    # Create DataFrame from the data list
    data_df = pd.DataFrame(data, columns=['Station_Name', 'Station_Address'])
    data.clear()

    # Generate a UUID for each row based on the values in 'Station_Name' and 'Station_Address'
    generate_uuid = lambda row: uuid.uuid5(uuid.NAMESPACE_DNS, str(row['Station_Name']) + str(row['Station_Address'])).hex

    # Add new columns to the created DataFrame
    data_df["country"] = ctry
    data_df['id'] = data_df.apply(generate_uuid, axis=1)

    #Rearrange DataFrame
    data_df = data_df[['id', 'Station_Name', 'Station_Address', 'country']]
    
    # Save the Data to DB
    save_data(data_df)

        

for url, ctry in zip(country_url_list, countries):
    try:
        # Scrape the page and save data
        get_and_save_data(url, ctry)        
        
        # Get and prepare Pagination        
        page_n = get_pagination(url)
        if get_pagi_url_max_num(page_n):
            print('More')
            pgination_url, max_pg = get_pagi_url_max_num(page_n)
            for i in range(2, max_pg + 1):  # range(2, max_pg+1)
                get_and_save_data(pgination_url+str(i), ctry)
        else:
            print('less')
            continue
        
    except Exception as err:
        print(err)
# Out:
# France https://www.viamichelin.fr/web/Stations-service?address=France <Response [200]>
# 48 48
# id                 2392873b80645709b79ebc7afaf057f0
# Station_Name                       CARREFOUR Market
# Station_Address       route de vire, 50000 Saint-Lô
# country                                      France
# Name: 0, dtype: object
# More
# France https://www.viamichelin.fr/web/Stations-service/Stations-service-France?page=2 <Response [200]>
# 48 48
# id                             6b055a4ea7005feb9b34de6f00d6668d
# Station_Name                                            HYPER U
# Station_Address    Voie des Alliés, 14440 DOUVRES-LA-DéLIVRANDE
# country                                                  France
# Name: 0, dtype: object
# France https://www.viamichelin.fr/web/Stations-service/Stations-service-France?page=3 <Response [200]>
# 48 48
# id                 c04539d04e295e25aaceb15cfb5f9e79
# Station_Name                            AVIA XPRESS
# Station_Address            RD N 3 -, 21260 SELONGEY
# country                                      France
# Name: 0, dtype: object
# France https://www.viamichelin.fr/web/Stations-service/Stations-service-France?page=4 <Response [200]>
# 48 48
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [152], in <cell line: 130>()
#     139     pgination_url, max_pg = get_pagi_url_max_num(page_n)
#     140     for i in range(2, max_pg + 1):  # range(2, max_pg+1)
# --> 141         get_and_save_data(pgination_url+str(i), ctry)
#     142 else:
#     143     print('less')
#
# Input In [152], in get_and_save_data(url, ctry)
#     123 data_df = data_df[['id', 'Station_Name', 'Station_Address', 'country']]
#     125 # Save the Data to DB
# --> 126 save_data(data_df)
#
# Input In [152], in save_data(data_df)
#      71 #print('Del Query is ', del_existing_rows_query)
#      72 with snow_engine.connect() as conn:
# ---> 73     conn.execute(del_existing_rows_query)
#      75 # Save data in the DataFrame
#      76 data_df.to_sql(target_table, con=snow_engine, schema='public', index=False, if_exists='append')
#
# File ~/opt/anaconda3/envs/route_env/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1365, in Connection.execute(self, statement, *multiparams, **params)
#    1356 if isinstance(statement, util.string_types):
#    1357     util.warn_deprecated_20(
#    1358         "Passing a string to Connection.execute() is "
#    1359         "deprecated and will be removed in version 2.0.  Use the "
#    (...)
#    1362         "driver-level SQL string."
#    1363     )
# -> 1365     return self._exec_driver_sql(
#    1366         statement,
#    1367         multiparams,
#    1368         params,
#    1369         _EMPTY_EXECUTION_OPTS,
#    1370         future=False,
#    1371     )
#    1373 try:
#    1374     meth = statement._execute_on_connection
#
# File ~/opt/anaconda3/envs/route_env/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1669, in Connection._exec_driver_sql(self, statement, multiparams, params, execution_options, future)
#    1659         (
#    1660             statement,
#    1661             distilled_params,
#    (...)
#    1665             statement, distilled_parameters, execution_options
#    1666         )
#    1668 dialect = self.dialect
# -> 1669 ret = self._execute_context(
#    1670     dialect,
#    1671     dialect.execution_ctx_cls._init_statement,
#    1672     statement,
#    1673     distilled_parameters,
#    1674     execution_options,
#    1675     statement,
#    1676     distilled_parameters,
#    1677 )
#    1679 if not future:
#    1680     if self._has_events or self.engine._has_events:
#
# File ~/opt/anaconda3/envs/route_env/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1943, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1940             branched.close()
#    1942 except BaseException as e:
# -> 1943     self._handle_dbapi_exception(
#    1944         e, statement, parameters, cursor, context
#    1945     )
#    1947 return result
#
# File ~/opt/anaconda3/envs/route_env/lib/python3.10/site-packages/sqlalchemy/engine/base.py:2128, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    2124         util.raise_(
#    2125             sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2126         )
#    2127     else:
# -> 2128         util.raise_(exc_info[1], with_traceback=exc_info[2])
#    2130 finally:
#    2131     del self._reentrant_error
#
# File ~/opt/anaconda3/envs/route_env/lib/python3.10/site-packages/sqlalchemy/util/compat.py:211, in raise_(***failed resolving arguments***)
#     208     exception.__cause__ = replace_context
#     210 try:
# --> 211     raise exception
#     212 finally:
#     213     # credit to
#     214     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     215     # as the __traceback__ object creates a cycle
#     216     del exception, replace_context, from_, with_traceback
#
# File ~/opt/anaconda3/envs/route_env/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1900, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1898                 break
#    1899     if not evt_handled:
# -> 1900         self.dialect.do_execute(
#    1901             cursor, statement, parameters, context
#    1902         )
#    1904 if self._has_events or self.engine._has_events:
#    1905     self.dispatch.after_cursor_execute(
#    1906         self,
#    1907         cursor,
#    (...)
#    1911         context.executemany,
#    1912     )
#
# File ~/opt/anaconda3/envs/route_env/lib/python3.10/site-packages/sqlalchemy/engine/default.py:736, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     735 def do_execute(self, cursor, statement, parameters, context=None):
# --> 736     cursor.execute(statement, parameters)
#
# File ~/opt/anaconda3/envs/route_env/lib/python3.10/site-packages/snowflake/connector/cursor.py:705, in SnowflakeCursor.execute(self, command, params, _bind_stage, timeout, _exec_async, _do_reset, _put_callback, _put_azure_callback, _put_callback_output_stream, _get_callback, _get_azure_callback, _get_callback_output_stream, _show_progress_bar, _statement_params, _is_internal, _describe_only, _no_results, _use_ijson, _is_put_get, _raise_put_get_error, _force_put_overwrite, file_stream)
#     703 if logger.getEffectiveLevel() <= logging.INFO:
#     704     logger.info("query: [%s]", self._format_query_for_log(query))
# --> 705 ret = self._execute_helper(query, **kwargs)
#     706 self._sfqid = (
#     707     ret["data"]["queryId"]
#     708     if "data" in ret and "queryId" in ret["data"]
#     709     else None
#     710 )
#     711 self._sqlstate = (
#     712     ret["data"]["sqlState"]
#     713     if "data" in ret and "sqlState" in ret["data"]
#     714     else None
#     715 )
#
# File ~/opt/anaconda3/envs/route_env/lib/python3.10/site-packages/snowflake/connector/cursor.py:508, in SnowflakeCursor._execute_helper(self, query, timeout, statement_params, binding_params, binding_stage, is_internal, describe_only, _no_results, _is_put_get)
#     506 ret = {"data": {}}
#     507 try:
# --> 508     ret = self._connection.cmd_query(
#     509         query,
#     510         self._sequence_counter,
#     511         self._request_id,
#     512         binding_params=binding_params,
#     513         binding_stage=binding_stage,
#     514         is_file_transfer=bool(self._is_file_transfer),
#     515         statement_params=statement_params,
#     516         is_internal=is_internal,
#     517         describe_only=describe_only,
#     518         _no_results=_no_results,
#     519     )
#     520 finally:
#     521     try:
#
# File ~/opt/anaconda3/envs/route_env/lib/python3.10/site-packages/snowflake/connector/connection.py:955, in SnowflakeConnection.cmd_query(self, sql, sequence_counter, request_id, binding_params, binding_stage, is_file_transfer, statement_params, is_internal, describe_only, _no_results, _update_current_object)
#     946     logger.debug(
#     947         "sql=[%s], sequence_id=[%s], is_file_transfer=[%s]",
#     948         self._format_query_for_log(data["sqlText"]),
#     949         data["sequenceId"],
#     950         is_file_transfer,
#     951     )
#     953 url_parameters = {REQUEST_ID: request_id}
# --> 955 ret = self.rest.request(
#     956     "/queries/v1/query-request?" + urlencode(url_parameters),
#     957     data,
#     958     client=client,
#     959     _no_results=_no_results,
#     960     _include_retry_params=True,
#     961 )
#     963 if ret is None:
#     964     ret = {"data": {}}
#
# File ~/opt/anaconda3/envs/route_env/lib/python3.10/site-packages/snowflake/connector/network.py:462, in SnowflakeRestful.request(self, url, body, method, client, _no_results, timeout, _include_retry_params)
#     460     headers[HTTP_HEADER_SERVICE_NAME] = self._connection.service_name
#     461 if method == "post":
# --> 462     return self._post_request(
#     463         url,
#     464         headers,
#     465         json.dumps(body),
#     466         token=self.token,
#     467         _no_results=_no_results,
#     468         timeout=timeout,
#     469         _include_retry_params=_include_retry_params,
#     470     )
#     471 else:
#     472     return self._get_request(url, headers, token=self.token, timeout=timeout)
#
# File ~/opt/anaconda3/envs/route_env/lib/python3.10/site-packages/snowflake/connector/network.py:700, in SnowflakeRestful._post_request(self, url, headers, body, token, timeout, _no_results, no_retry, socket_timeout, _include_retry_params)
#     697     ret = probe_connection(full_url)
#     698     pprint(ret)
# --> 700 ret = self.fetch(
#     701     "post",
#     702     full_url,
#     703     headers,
#     704     data=body,
#     705     timeout=timeout,
#     706     token=token,
#     707     no_retry=no_retry,
#     708     socket_timeout=socket_timeout,
#     709     _include_retry_params=_include_retry_params,
#     710 )
#     711 logger.debug(
#     712     "ret[code] = {code}, after post request".format(
#     713         code=(ret.get("code", "N/A"))
#     714     )
#     715 )
#     717 if ret.get("code") == SESSION_EXPIRED_GS_CODE:
#
# File ~/opt/anaconda3/envs/route_env/lib/python3.10/site-packages/snowflake/connector/network.py:790, in SnowflakeRestful.fetch(self, method, full_url, headers, data, timeout, **kwargs)
#     788 retry_ctx = RetryCtx(timeout, include_retry_params)
#     789 while True:
# --> 790     ret = self._request_exec_wrapper(
#     791         session, method, full_url, headers, data, retry_ctx, **kwargs
#     792     )
#     793     if ret is not None:
#     794         return ret
#
# File ~/opt/anaconda3/envs/route_env/lib/python3.10/site-packages/snowflake/connector/network.py:833, in SnowflakeRestful._request_exec_wrapper(self, session, method, full_url, headers, data, retry_ctx, no_retry, token, **kwargs)
#     831 full_url = SnowflakeRestful.add_request_guid(full_url)
#     832 try:
# --> 833     return_object = self._request_exec(
#     834         session=session,
#     835         method=method,
#     836         full_url=full_url,
#     837         headers=headers,
#     838         data=data,
#     839         token=token,
#     840         **kwargs,
#     841     )
#     842     if return_object is not None:
#     843         return return_object
#
# File ~/opt/anaconda3/envs/route_env/lib/python3.10/site-packages/snowflake/connector/network.py:988, in SnowflakeRestful._request_exec(self, session, method, full_url, headers, data, token, catch_okta_unauthorized_error, is_raw_text, is_raw_binary, binary_data_handler, socket_timeout)
#     984 download_start_time = get_time_millis()
#     985 # socket timeout is constant. You should be able to receive
#     986 # the response within the time. If not, ConnectReadTimeout or
#     987 # ReadTimeout is raised.
# --> 988 raw_ret = session.request(
#     989     method=method,
#     990     url=full_url,
#     991     headers=headers,
#     992     data=input_data,
#     993     timeout=socket_timeout,
#     994     verify=True,
#     995     stream=is_raw_binary,
#     996     auth=SnowflakeAuth(token),
#     997 )
#     998 download_end_time = get_time_millis()
#    1000 try:
#
# File ~/opt/anaconda3/envs/route_env/lib/python3.10/site-packages/snowflake/connector/vendored/requests/sessions.py:542, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     537 send_kwargs = {
#     538     'timeout': timeout,
#     539     'allow_redirects': allow_redirects,
#     540 }
#     541 send_kwargs.update(settings)
# --> 542 resp = self.send(prep, **send_kwargs)
#     544 return resp
#
# File ~/opt/anaconda3/envs/route_env/lib/python3.10/site-packages/snowflake/connector/vendored/requests/sessions.py:655, in Session.send(self, request, **kwargs)
#     652 start = preferred_clock()
#     654 # Send the request
# --> 655 r = adapter.send(request, **kwargs)
#     657 # Total elapsed time of the request (approximately)
#     658 elapsed = preferred_clock() - start
#
# File ~/opt/anaconda3/envs/route_env/lib/python3.10/site-packages/snowflake/connector/vendored/requests/adapters.py:439, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     437 try:
#     438     if not chunked:
# --> 439         resp = conn.urlopen(
#     440             method=request.method,
#     441             url=url,
#     442             body=request.body,
#     443             headers=request.headers,
#     444             redirect=False,
#     445             assert_same_host=False,
#     446             preload_content=False,
#     447             decode_content=False,
#     448             retries=self.max_retries,
#     449             timeout=timeout
#     450         )
#     452     # Send the request.
#     453     else:
#     454         if hasattr(conn, 'proxy_pool'):
#
# File ~/opt/anaconda3/envs/route_env/lib/python3.10/site-packages/snowflake/connector/vendored/urllib3/connectionpool.py:699, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     696     self._prepare_proxy(conn)
#     698 # Make the request on the httplib connection object.
# --> 699 httplib_response = self._make_request(
#     700     conn,
#     701     method,
#     702     url,
#     703     timeout=timeout_obj,
#     704     body=body,
#     705     headers=headers,
#     706     chunked=chunked,
#     707 )
#     709 # If we're going to release the connection in ``finally:``, then
#     710 # the response doesn't need to know about the connection. Otherwise
#     711 # it will also try to release it and we'll have a double-release
#     712 # mess.
#     713 response_conn = conn if not release_conn else None
#
# File ~/opt/anaconda3/envs/route_env/lib/python3.10/site-packages/snowflake/connector/vendored/urllib3/connectionpool.py:445, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     440             httplib_response = conn.getresponse()
#     441         except BaseException as e:
#     442             # Remove the TypeError from the exception chain in
#     443             # Python 3 (including for exceptions like SystemExit).
#     444             # Otherwise it looks like a bug in the code.
# --> 445             six.raise_from(e, None)
#     446 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     447     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~/opt/anaconda3/envs/route_env/lib/python3.10/site-packages/snowflake/connector/vendored/urllib3/connectionpool.py:440, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     437 except TypeError:
#     438     # Python 3
#     439     try:
# --> 440         httplib_response = conn.getresponse()
#     441     except BaseException as e:
#     442         # Remove the TypeError from the exception chain in
#     443         # Python 3 (including for exceptions like SystemExit).
#     444         # Otherwise it looks like a bug in the code.
#     445         six.raise_from(e, None)
#
# File ~/opt/anaconda3/envs/route_env/lib/python3.10/http/client.py:1374, in HTTPConnection.getresponse(self)
#    1372 try:
#    1373     try:
# -> 1374         response.begin()
#    1375     except ConnectionError:
#    1376         self.close()
#
# File ~/opt/anaconda3/envs/route_env/lib/python3.10/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File ~/opt/anaconda3/envs/route_env/lib/python3.10/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File ~/opt/anaconda3/envs/route_env/lib/python3.10/socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File ~/opt/anaconda3/envs/route_env/lib/python3.10/site-packages/snowflake/connector/vendored/urllib3/contrib/pyopenssl.py:331, in WrappedSocket.recv_into(self, *args, **kwargs)
#     329         raise
#     330 except OpenSSL.SSL.WantReadError:
# --> 331     if not util.wait_for_read(self.socket, self.socket.gettimeout()):
#     332         raise timeout("The read operation timed out")
#     333     else:
#
# File ~/opt/anaconda3/envs/route_env/lib/python3.10/site-packages/snowflake/connector/vendored/urllib3/util/wait.py:146, in wait_for_read(sock, timeout)
#     142 def wait_for_read(sock, timeout=None):
#     143     """Waits for reading to be available on a given socket.
#     144     Returns True if the socket is readable, or False if the timeout expired.
#     145     """
# --> 146     return wait_for_socket(sock, read=True, timeout=timeout)
#
# File ~/opt/anaconda3/envs/route_env/lib/python3.10/site-packages/snowflake/connector/vendored/urllib3/util/wait.py:107, in poll_wait_for_socket(sock, read, write, timeout)
#     104         t *= 1000
#     105     return poll_obj.poll(t)
# --> 107 return bool(_retry_on_intr(do_poll, timeout))
#
# File ~/opt/anaconda3/envs/route_env/lib/python3.10/site-packages/snowflake/connector/vendored/urllib3/util/wait.py:43, in _retry_on_intr(fn, timeout)
#      42 def _retry_on_intr(fn, timeout):
# ---> 43     return fn(timeout)
#
# File ~/opt/anaconda3/envs/route_env/lib/python3.10/site-packages/snowflake/connector/vendored/urllib3/util/wait.py:105, in poll_wait_for_socket.<locals>.do_poll(t)
#     103 if t is not None:
#     104     t *= 1000
# --> 105 return poll_obj.poll(t)
#
# File ~/opt/anaconda3/envs/route_env/lib/python3.10/site-packages/snowflake/connector/cursor.py:497, in SnowflakeCursor._execute_helper.<locals>.interrupt_handler(*_)
#     494         except (ValueError, TypeError):
#     495             # ignore failures
#     496             pass
# --> 497 raise KeyboardInterrupt
#
# KeyboardInterrupt:

# %%
for url, ctry in zip(country_url_list, countries):
    print(ctry,'\n',url)
# Out:
# France
#  https://www.viamichelin.fr/web/Stations-service?address=France
# United Kingdom
#  https://www.viamichelin.fr/web/Stations-service?address=united%20kingdom
# Switzerland
#  https://www.viamichelin.fr/web/Stations-service?address=switzerland
# Germany
#  https://www.viamichelin.fr/web/Stations-service?address=germany
# Belgium
#  https://www.viamichelin.fr/web/Stations-service?address=Belgium
# Netherlands
#  https://www.viamichelin.fr/web/Stations-service?address=netherlands
# Spain
#  https://www.viamichelin.fr/web/Stations-service?address=spain
# Luxembourg
#  https://www.viamichelin.fr/web/Stations-service?address=luxemburg
# Czech Republic
#  https://www.viamichelin.fr/web/Stations-service?address=Czechia
# Italy
#  https://www.viamichelin.fr/web/Stations-service?address=Italy

# %%
def get_rqt(url):
    r = requests.get(url)
    sp = BeautifulSoup(r.content, 'html.parser')
    return sp


def get_pagi_url_max_num(page_n):
    pg = BeautifulSoup(str(page_n[0]), 'html.parser')
    pg_a = pg.findAll('a')

    if len(pg_a) > 0:
        pg_a = pg_a[-1]
        pgination_url = pg_a['href']
        pgination_url = pgination_url[0:pgination_url.index('=')+1]
        max_pg = int(pg_a.get_text())
        return pgination_url, max_pg
    
    
def get_pagination(url):
    r = requests.get(url)
    #print(r)
    soup = BeautifulSoup(r.content, 'html.parser')
    page_n = soup.findAll("p", class_="pagination-second-line")
    return page_n


def save_data(data_df):
    target_table = 'viamichelin_stations'
    del_id_lst = str(list(data_df['id'])).replace('[','(').replace(']',')')    
    try:
        # Delete existing rows to be updated with new version
        del_existing_rows_query = "DELETE FROM " +target_table+ " WHERE id IN " + del_id_lst
        with snow_engine.connect() as conn:
            conn.execute(del_existing_rows_query)

        # Save data in the DataFrame    
        data_df.to_sql(target_table, con=snow_engine, schema='public', index=False, if_exists='append')
        print('done')
    except Exception as err:
        print(err)    

    
def get_and_save_data(url, ctry):
    r = requests.get(url)
    print(url, r)
    soup = BeautifulSoup(r.content, 'html.parser')

    # Get station Names
    station_names = soup.findAll('div', class_='poi-item-name truncate')
    station_names = [val.get_text() for val in station_names]

    # Get station Addresses
    station_address = soup.findAll('div', class_="poi-item-details-address truncate")
    station_address = [val.get_text() for val in station_address]
    print(len(station_names), len(station_address))

    # Combine the Scrapped data into a list ready to be converted into a DataFrame
    dat_zip = zip(station_names[:2], station_address[:2])

    # Clear the list to save memory        
    station_names.clear()
    station_address.clear()

    zipped_dat = list(dat_zip)
    dat_zip = ''
    data = [list(i) for i in zipped_dat]
    zipped_dat.clear()

    # Create DataFrame from the data list
    data_df = pd.DataFrame(data, columns=['Station_Name', 'Station_Address'])
    data.clear()

    # Generate a UUID for each row based on the values in 'Station_Name' and 'Station_Address'
    generate_uuid = lambda row: uuid.uuid5(uuid.NAMESPACE_DNS, str(row['Station_Name']) + str(row['Station_Address'])).hex

    # Add new columns to the created DataFrame
    data_df["country"] = ctry
    data_df['id'] = data_df.apply(generate_uuid, axis=1)

    #Rearrange DataFrame
    data_df = data_df[['id', 'Station_Name', 'Station_Address', 'country']]
    
    # Save the Data to DB
    save_data(data_df)
    data_df
    print(data_df)
        

for url, ctry in zip(country_url_list, countries):
    try:
        # Scrape the page and save data
        get_and_save_data(url, ctry)        
        
        # Get and prepare Pagination        
        page_n = get_pagination(url)
        if get_pagi_url_max_num(page_n):
            print('More')
            pgination_url, max_pg = get_pagi_url_max_num(page_n)
            for i in range(2, (max_pg-max_pg) + 4):  # range(2, max_pg+1)
                get_and_save_data(pgination_url+str(i), ctry)
        else:
            print('less')
            continue
        
    except Exception as err:
        print(err)
# Out:
# https://www.viamichelin.fr/web/Stations-service?address=Czechia <Response [200]>
# 48 48
# done
#                                  id        Station_Name  \
# 0  0db0c81b1cba5668b692cc09a66d2264           MOL Ruská
# 1  ef3a0ce755ce52a8b4e51f15b127281e  EuroOil Havlíčkova
#
#                    Station_Address country
# 0            Ruská, 10000 Praha 10  France
# 1  1673 Havlíčkova, 58301 Chotěboř  France
# More
# https://www.viamichelin.fr/web/Stations-service/Stations-service-Tchequie?page=2 <Response [200]>
# 48 48
# done
#                                  id       Station_Name  \
# 0  93cdced41f9252f98757d1fce95f6477  EuroOil Břidličná
# 1  be43f06ea5835deba9e45c4376fcd489         MOL Karlov
#
#                      Station_Address country
# 0    488 Rýmařovská, 79351 Břidličná  France
# 1  1247 Karlov, 59401 Velké Meziříčí  France
# https://www.viamichelin.fr/web/Stations-service/Stations-service-Tchequie?page=3 <Response [200]>
# 48 48
# done
#                                  id   Station_Name  \
# 0  fe957e7aac87593ab5f98a7d9c933302  Shell Šumperk
# 1  1e3a96d5c5455cb686ba132fa1a11ea3       Těšetice
#
#                     Station_Address country
# 0  2846/1C Jesenická, 78701 Šumperk  France
# 1                                    France

# %%
for url, ctry in zip(country_url_list, countries):
    print(url, ctry)
# Out:
# https://www.viamichelin.fr/web/Stations-service?address=Czechia France

# %%
ulr = 'https://www.viamichelin.fr/web/Stations-service?address=Czechia'

# %%
r = requests.get(ulr)
r
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(r.content, 'html.parser')
#print(soup.prettify())

# %%
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
[i.get_text() for i in soup.findAll('div', class_='poi-item-details-address truncate')[:5]]
# Out:
# ['Ruská, 10000 Praha 10',
#  '1673 Havlíčkova, 58301 Chotěboř',
#  '',
#  '1452/20 Dvorní, 57101 Moravská Třebová',
#  '825/4 Roviny, 64300 Brno-Chrlice']

# %%
station_names = soup.findAll('div', class_='poi-item-name truncate')
station_names = [val.get_text() for val in station_names]
station_names[:5]
# Out:
# ['MOL Ruská',
#  'EuroOil Havlíčkova',
#  'Benzina Nová Houžná',
#  'OMV Moravská Třebová',
#  'AD']

# %%
len(station_names)
# Out:
# 48

# %%
df_data = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]})
df_data
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6

# %%
print(df_data.loc[0])
# Out:
# A    1
# B    4
# Name: 0, dtype: int64

# %%
type(station_names[3])
# Out:
# str

# %%
station_address = soup.findAll('div', class_="poi-item-details-address truncate")
station_address = [val.get_text() for val in station_address]
station_address[:5]
# Out:
# ['Ruská, 10000 Praha 10',
#  '1673 Havlíčkova, 58301 Chotěboř',
#  '',
#  '1452/20 Dvorní, 57101 Moravská Třebová',
#  '825/4 Roviny, 64300 Brno-Chrlice']

# %%
needed_data = [station_names, station_address]
#needed_data

# %%
dat_zip = zip(station_names[:2], station_address[:2])
zipped_dat = list(dat_zip)
dat_zip = ''
data = [list(i) for i in zipped_dat]
zipped_dat.clear()
print(data)
# Out:
# [['MOL Ruská', 'Ruská, 10000 Praha 10'], ['EuroOil Havlíčkova', '1673 Havlíčkova, 58301 Chotěboř']]

# %%
type(zipped_dat)
# Out:
# list

# %%
import uuid
import hashlib

namespace = uuid.UUID('6ba7b810-9dad-11d1-80b4-00c04fd430c8')
input_string = "my_stringt"

uuid_val = uuid.uuid5(namespace, input_string)

print(uuid_val)
# Out:
# d0e00062-2ca8-5e7f-9915-e837894327d2

# %%
def generate_id(input_string):
    namespace = uuid.UUID('6ba7b810-9dad-11d1-80b4-00c04fd430c8')
    uuid_val = uuid.uuid5(namespace, input_string)
    return str(uuid_val)

# %%
def generate_id(df):
    namespace = uuid.UUID('6ba7b810-9dad-11d1-80b4-00c04fd430c8')
    uuid_val = uuid.uuid5(namespace, str(df['Station_Name'])+str(df['Station_Address']) )
    return str(uuid_val)

# %%
uuid_value = generate_id(str(data_df['Station_Name'])+str(data_df['Station_Address']))
uuid_value
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [31], in <cell line: 1>()
# ----> 1 uuid_value = generate_id(str(data_df['Station_Name'])+str(data_df['Station_Address']))
#       2 uuid_value
#
# NameError: name 'data_df' is not defined

# %%
str(uuid_value)
# Out:
# 'd98ee33c-9e04-5e58-aae8-4173c4e6842a'

# %%
# Generate a UUID for each row based on the values in 'Station_Name' and 'Station_Address'
generate_uuid = lambda row: uuid.uuid5(uuid.NAMESPACE_DNS, str(row['Station_Name']) + str(row['Station_Address'])).hex

data_df = pd.DataFrame(data, columns=['Station_Name', 'Station_Address'])
data_df["country"] = 'France'
data_df['id'] = data_df.apply(generate_uuid, axis=1)

#Rearrange DataFrame
data_df = data_df[['id', 'Station_Name', 'Station_Address', 'country']]
data_df
# Out:
#                                  id        Station_Name  \
# 0  0db0c81b1cba5668b692cc09a66d2264           MOL Ruská
# 1  ef3a0ce755ce52a8b4e51f15b127281e  EuroOil Havlíčkova
#
#                    Station_Address country
# 0            Ruská, 10000 Praha 10  France
# 1  1673 Havlíčkova, 58301 Chotěboř  France

# %%
data_df = data_df[['id', 'Station_Name', 'Station_Address', 'country']]
data_df
# Out:
#                                  id        Station_Name  \
# 0  0db0c81b1cba5668b692cc09a66d2264           MOL Ruská
# 1  ef3a0ce755ce52a8b4e51f15b127281e  EuroOil Havlíčkova
#
#                    Station_Address country
# 0            Ruská, 10000 Praha 10  France
# 1  1673 Havlíčkova, 58301 Chotěboř  France

# %%
data_df
# Out:
#                                  id        Station_Name  \
# 0  0db0c81b1cba5668b692cc09a66d2264           MOL Ruská
# 1  ef3a0ce755ce52a8b4e51f15b127281e  EuroOil Havlíčkova
#
#                    Station_Address country
# 0            Ruská, 10000 Praha 10  France
# 1  1673 Havlíčkova, 58301 Chotěboř  France

# %%
data_df
# Out:
#                                  id        Station_Name  \
# 0  0db0c81b1cba5668b692cc09a66d2264           MOL Ruská
# 1  ef3a0ce755ce52a8b4e51f15b127281e  EuroOil Havlíčkova
#
#                    Station_Address country
# 0            Ruská, 10000 Praha 10  France
# 1  1673 Havlíčkova, 58301 Chotěboř  France

# %%
snow_engine = create_engine(URL(
    account = config['account'],
    user = config['user'],
    password = config['password'],
    database = config['database'],
    schema = config['schema'],
    warehouse = config['warehouse'],
    role= config['role']
))

snow_connection = snow_engine.connect()
snow_connection

# %%
data_df
# Out:
#                                  id        Station_Name  \
# 0  0db0c81b1cba5668b692cc09a66d2264           MOL Ruská
# 1  ef3a0ce755ce52a8b4e51f15b127281e  EuroOil Havlíčkova
#
#                    Station_Address country
# 0            Ruská, 10000 Praha 10  France
# 1  1673 Havlíčkova, 58301 Chotěboř  France

# %%
snow_engine

# %%
lst = list(data_df['id'])
lst
# Out:
# ['0db0c81b1cba5668b692cc09a66d2264', 'ef3a0ce755ce52a8b4e51f15b127281e']

# %%
for i in lst

# %%
import numpy as np
data_df['country'] = np.where(data_df['id'] == '0db0c81b1cba5668b692cc09a66d2264', 'Czech Republic', data_df['country'])
data_df = data_df.head(1)
data_df
# Out:
#                                  id Station_Name        Station_Address  \
# 0  0db0c81b1cba5668b692cc09a66d2264    MOL Ruská  Ruská, 10000 Praha 10
#
#           country
# 0  Czech Republic

# %%
data_df[data_df['id'] == '0db0c81b1cba5668b692cc09a66d2264'].country = 'Czech Republic'
data_df
# Out:
# /var/folders/vp/c_kgx06n7dq2rtfy8_mhq1dw0000gp/T/ipykernel_31559/440371380.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_df[data_df['id'] == '0db0c81b1cba5668b692cc09a66d2264'].country = 'Czech Republic'
#                                  id        Station_Name  \
# 0  0db0c81b1cba5668b692cc09a66d2264           MOL Ruská
# 1  ef3a0ce755ce52a8b4e51f15b127281e  EuroOil Havlíčkova
#
#                    Station_Address country
# 0            Ruská, 10000 Praha 10  France
# 1  1673 Havlíčkova, 58301 Chotěboř  France

# %%
data_df
# Out:
#                                  id Station_Name        Station_Address  \
# 0  0db0c81b1cba5668b692cc09a66d2264    MOL Ruská  Ruská, 10000 Praha 10
#
#           country
# 0  Czech Republic

# %%
target_table = 'viamichelin_stations'
del_id_lst = str(list(data_df['id'])).replace('[','(').replace(']',')')    
try:
    # Delete existing rows to be updated with new version
    del_existing_rows_query = "DELETE FROM " +target_table+ " WHERE id IN " + del_id_lst
    with snow_engine.connect() as conn:
        conn.execute(del_existing_rows_query)
        
    # Save data in the DataFrame    
    data_df.to_sql(target_table, con=snow_engine, schema='public', index=False, if_exists='append')
    print('done')
except Exception as err:
    print(err)
# Out:
# done

# %%
def save_data(data_df):
    target_table = 'viamichelin_stations'
    del_id_lst = str(list(data_df['id'])).replace('[','(').replace(']',')')    
    try:
        # Delete existing rows to be updated with new version
        del_existing_rows_query = "DELETE FROM " +target_table+ " WHERE id IN " + del_id_lst
        with snow_engine.connect() as conn:
            conn.execute(del_existing_rows_query)

        # Save data in the DataFrame    
        data_df.to_sql(target_table, con=snow_engine, schema='public', index=False, if_exists='append')
        print('done')
    except Exception as err:
        print(err)

# %%
str(tuple(data_df['id']))
# Out:
# "('0db0c81b1cba5668b692cc09a66d2264',)"

# %%
del_id_lst = str(list(data_df['id'])).replace('[','(').replace(']',')')
del_id_lst
# Out:
# "('0db0c81b1cba5668b692cc09a66d2264')"

# %%
str(list(data_df['id'])).replace('[','(').replace(']',')')
# Out:
# "('0db0c81b1cba5668b692cc09a66d2264')"

# %%
target_table
# Out:
# 'viamichelin_stations'

# %%
# MY_DATABASE
try:
    data_df.to_sql(target_table, con=snow_engine, schema='public', index=False, if_exists='append')
    print('done')
except Exception as err:
    print(err)
# Out:
# done

# %%
data_df
# Out:
#                                  id        Station_Name  \
# 0  0db0c81b1cba5668b692cc09a66d2264           MOL Ruská
# 1  ef3a0ce755ce52a8b4e51f15b127281e  EuroOil Havlíčkova
#
#                    Station_Address country
# 0            Ruská, 10000 Praha 10  France
# 1  1673 Havlíčkova, 58301 Chotěboř  France

# %%
# %%time
tab = 'sno_engine_conn_insert'
data_df.to_sql(f'{tab}', snow_engine, if_exists='replace', index=False)
# Out:
# CPU times: user 91.6 ms, sys: 14.2 ms, total: 106 ms
# Wall time: 3.49 s

# %%
page_n = soup.findAll("p", class_="pagination-second-line")
page_n
# Out:
# [<p class="pagination-second-line"> <a data-pagination="20" href="https://www.viamichelin.fr/web/Stations-service/Stations-service-Tchequie?page=20">20</a> <a data-pagination="30" href="https://www.viamichelin.fr/web/Stations-service/Stations-service-Tchequie?page=30">30</a> <a data-pagination="40" href="https://www.viamichelin.fr/web/Stations-service/Stations-service-Tchequie?page=40">40</a> <a data-pagination="50" href="https://www.viamichelin.fr/web/Stations-service/Stations-service-Tchequie?page=50">50</a></p>]

# %%
page_n = soup.findAll("p", class_="pagination-second-line")
def get_pagi_url_max_num(page_n):
    pg = BeautifulSoup(str(page_n[0]), 'html.parser')
    pg_a = pg.findAll('a')

    if len(pg_a) < 0:
        pg_a = pg_a[-1]
        pgination_url = pg_a['href']
        pgination_url = pgination_url[0:pgination_url.index('=')+1]
        max_pg = int(pg_a.get_text())
        return pgination_url, max_pg

# %%
try:
    get_pagi_url_max_num(page_n)
    print('More')
except:
    print('less')
# Out:
# More

# %%
if get_pagi_url_max_num(page_n):
    print('More')
    pgination_url, max_pg = get_pagi_url_max_num(page_n)
else:
    print('less')
# Out:
# More

# %%
page_n = soup.findAll("p", class_="pagination-second-line")
pg = BeautifulSoup(str(page_n[0]), 'html.parser')
pg_a = pg.findAll('a')

if len(pg_a) > 0:
    pg_a = pg_a[-1]
    pgination_url = pg_a['href']
    pgination_url = pgination_url[0:pgination_url.index('=')+1]
    max_pg = int(pg_a.get_text())
    pgination_url max_pg

# %%
#page_n =
pg = BeautifulSoup(str(page_n[0]), 'html.parser')
pg
# Out:
# <p class="pagination-second-line"> <a data-pagination="20" href="https://www.viamichelin.fr/web/Stations-service/Stations-service-Tchequie?page=20">20</a> <a data-pagination="30" href="https://www.viamichelin.fr/web/Stations-service/Stations-service-Tchequie?page=30">30</a> <a data-pagination="40" href="https://www.viamichelin.fr/web/Stations-service/Stations-service-Tchequie?page=40">40</a> <a data-pagination="50" href="https://www.viamichelin.fr/web/Stations-service/Stations-service-Tchequie?page=50">50</a></p>

# %%
pg_a = pg.findAll('a')
pg_a
# Out:
# [<a data-pagination="20" href="https://www.viamichelin.fr/web/Stations-service/Stations-service-Tchequie?page=20">20</a>,
#  <a data-pagination="30" href="https://www.viamichelin.fr/web/Stations-service/Stations-service-Tchequie?page=30">30</a>,
#  <a data-pagination="40" href="https://www.viamichelin.fr/web/Stations-service/Stations-service-Tchequie?page=40">40</a>,
#  <a data-pagination="50" href="https://www.viamichelin.fr/web/Stations-service/Stations-service-Tchequie?page=50">50</a>]

# %%
if len(pg_a) > 0:
    pg_a = pg_a[-1]
    pgination_url = pg_a['href']
    pgination_url = pgination_url[0:pgination_url.index('=')+1]
    max_pg = int(pg_a.get_text())

# %%
pgination_url
# Out:
# 'https://www.viamichelin.fr/web/Stations-service/Stations-service-Tchequie?page='

# %%
max_pg
# Out:
# 50

# %%
pgination_url[0:pgination_url.index('=')+1]
# Out:
# 'https://www.viamichelin.fr/web/Stations-service/Stations-service-Tchequie?page='
